# %% [markdown]
# ## Scenario Descriptions

# %% [markdown]
# ### CAGE Challenge 2

# %% [markdown]
# Your firm has been contracted by Florin to trial your new autonomous defence agents. Florin have given your agent authority to defend the computer network at one of their manufacturing plants. The network, shown in Figure 1, contains a user network for staff, an enterprise network, and an operational network which contains the key manufacturing and logistics servers. The defence agent receives an alert feed from Florin’s existing monitoring systems. It can run detailed analyses on hosts, then remove malicious software if found. If an attacker is too well established on a host to be removed, the host can be restored from a clean backup. Finally, the defence agent can deceive attackers by creating decoy services.
#
# The network owner has undertaken an evaluation of the factory systems and contracted your firm to defend these systems according to the following criteria:
#
# Maintain the critical operational server to ensure information about the new weapon system is not revealed to Guilder and the production and delivery of the new weapon system remains on schedule.
# Where possible, maintain enterprise servers to ensure day-to-day operations of the manufacturing plant are not disrupted or revealed.”

# %% [markdown]
# Subnet 1 consists of user hosts that are not critical. \
# Subnet 2 consists of enterprise servers designed to support the user activities on Subnet 1. \
# Subnet 3 contains the critical operational server and three user hosts.
#
# <img src="https://github.com/cage-challenge/cage-challenge-2/raw/main/images/figure1.png">
#
# The effect of each action on the state of a targeted host is summarized with the diagram.
#
# <img src="https://github.com/cage-challenge/cage-challenge-2/raw/main/images/figure2.png" caption="State Diagram">

# %% [markdown]
# ### Appendix - Action Sets

# %% [markdown]
# Blue Action Sets
#
# | Action     | Purpose                                                                                                                                                                                                                                                 | Parameters                                                                    | Output                                 |
# |:-----------|:--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:------------------------------------------------------------------------------|:---------------------------------------|
# | Monitor | Collection of information about flagged malicious activity on the system\. Corresponds to action ID 1: Scan in the OpenC2 specification[^3]\.                                                                                                           | None *\(Note: This action occurs automatically if another action is chosen\)* | Network connections and associated processes that are identified as malicious\. |
# | Analyse | Collection of further information on a specific host to enable blue to better identify if red is present on the system\. Corresponds to action ID 30: Investigate in the OpenC2 specification\.                                                         | Hostname                                                                      | Information on files associated with recent alerts including signature and entropy\.  |
# | DecoyApache, DecoyFemitter, DecoyHarakaSMPT, DecoySmss, DecoySSHD, DecoySvchost, DecoyTomcat | Setup of a decoy service (as specified by the action name) on a specified host\. Green agents do not access these services, so any access is a clear example of red activity\.                                                                                                            | Hostname                                                                | An alert if the red agent accesses the new service\. |
# | Remove | Attempting to remove red from a host by destroying malicious processes, files and services\. This action attempts to stop all processes identified as malicious by the monitor action\. Corresponds to action ID 10: Stop in the OpenC2 specification\. | Hostname                                                                      | Success/Failure |
# | Restore | Restoring a system to a known good state\. This has significant consequences for system availability\. This action punishes Blue by \-1\. Corresponds to action ID 23: Restore in the OpenC2 specification\.                                            | Hostname                                                                      | Success/Failure  |
#
# Red Action Sets
#
# | Action     | Purpose                                                                                                                                                    | Parameters       | Output                                 |
# |:-----------|:-----------------------------------------------------------------------------------------------------------------------------------------------------------|:-----------------|:---------------------------------------|
# | Discover Remote Systems | ATT&CK[^4] Technique T1018 Remote System Discovery\. Discovers new hosts/IP addresses in the network through active scanning using tools such as ping\.    | Subnet           | IP addresses in the chosen subnet from hosts that respond to ping |
# | Discover Network Services | ATT&CK Technique T1046 Network Service Scanning. Discovers responsive services on a selected host by initiating a connection with that host\.              | Subnet           | Ports and service information |
# | Exploit Network Services | ATT&CK Technique T1210 Exploitation of Remote Services\. This action attempts to exploit a specified service on a remote system\.                          | IP Address, Port | Success/Failure <br /> Initial recon of host if successful. |
# | Escalate | ATT&CK Tactic TA0004 Privilege Escalation\. This action escalates the agent’s privilege on the host\.                                                      | Hostname         | Success/Failure <p> Internal information now available due to increased access to the host |
# | Impact | ATT&CK Technique T1489 Service Stop\. This action disrupts the performance of the network and fulfils red’s objective of denying the operational service\. | Hostname         | Success/Failure  |

# %% [markdown]
# ### Agents

# %% [markdown]
# - Rules-based agents
# - Deep Reinforcement Learning agents

# %% [markdown]
# ### Rule-based agents

# %% [markdown]
# - Blue
#     - RandomAgent: Takes a random action or a test action based on the epsilon value
#     - BlueReactRemoveAgent: Adds suspicious hosts to the host list if the monitor finds something and then it will remove the program(session)
#     - BlueReactRestoreAgent: Similar steps but restore the host from a cleaned backup.
# - Red
#     - RedMeanderAgent: Explores the network one subnet at a time, seeking to gain privileged access to all hosts in a subnet before moving on to the next one, eventually arriving at the Operational Server.
#     - B_lineAgent: Attempts to move straight to the Operational Server using prior knowledge of the network layout.

# %%
from CybORG import CybORG
import inspect
import pprint

from CybORG.Agents import B_lineAgent, BlueReactRestoreAgent, BlueReactRemoveAgent, \
    RandomAgent, RedMeanderAgent
from CybORG.Agents.Wrappers import EnumActionWrapper
from CybORG.Agents.Wrappers.FixedFlatWrapper import FixedFlatWrapper
from CybORG.Agents.Wrappers.IntListToAction import IntListToActionWrapper
from CybORG.Agents.Wrappers.OpenAIGymWrapper import OpenAIGymWrapper
from CybORG.Simulator.Scenarios.FileReaderScenarioGenerator import FileReaderScenarioGenerator
# Out:
# /home/ubuntu/.local/lib/python3.10/site-packages/gym/wrappers/monitoring/video_recorder.py:9: DeprecationWarning: The distutils package is deprecated and slated for removal in Python 3.12. Use setuptools or check PEP 632 for potential alternatives
#   import distutils.spawn
# path is: /home/ubuntu/test/CybORG/CybORG/env.py

# %%
def run_episode_cc2(cyborg, agent):
    cyborg.reset()
    a = ''
    for i in range(20):
        # print(cyborg.environment_controller.get_last_action('Red'))
        # stop = cyborg.render()
        action_space = cyborg.get_action_space('Blue')
        # print(action_space)
        obs = cyborg.get_observation('Blue') # get the newest observation
        # print(f"obs is {obs}")
        # if stop:
        #     break
        action = agent.get_action(obs, action_space)
        print(f"===Perform the {i+1} step at CybORG level===")
        results = cyborg.step('Blue', action)
        # a = input(f'Step {i}, use q to quit, use n to go to next demo')
        # if 'q' in a:
        #     quit()
        # if 'n' in a:
        #     break

# %%
# input('start? ')
# CC2
path = str(inspect.getfile(CybORG))
path = path[:-7] + f'/Simulator/Scenarios/scenario_files/Scenario2.yaml'
sg = FileReaderScenarioGenerator(path)
red_agent = RedMeanderAgent()
cyborg = CybORG(sg, 'sim', agents={'Red': red_agent})
# Out:
# env is: sim
# /home/ubuntu/.local/lib/python3.10/site-packages/gym/utils/seeding.py:47: DeprecationWarning: WARN: Function `rng.randint(low, [high, size, dtype])` is marked as deprecated and will be removed in the future. Please use `rng.integers(low, [high, size, dtype])` instead.
#   deprecation(

# %%
# input('demo react remove')
agent = BlueReactRemoveAgent()
run_episode_cc2(cyborg, agent)
# Out:
# Agent Interfaces are: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a259420>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a259c00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a2598a0>}
# ===Perform the 1 step at CybORG level===
# action is: {'Blue': Monitor}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a259420>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a259c00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a2598a0>}
# action is: {'Blue': Monitor, 'Green': Sleep, 'Red': DiscoverRemoteSystems 10.0.232.0/28}
# --> in actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in actions
# In simcontroller execute action
# action is: DiscoverRemoteSystems 10.0.232.0/28 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.DiscoverRemoteSystems.DiscoverRemoteSystems'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# ===Perform the 2 step at CybORG level===
# action is: {'Blue': Monitor}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a259420>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a259c00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a2598a0>}
# action is: {'Blue': Monitor, 'Green': Sleep, 'Red': DiscoverNetworkServices 10.0.232.5}
# --> in actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in actions
# In simcontroller execute action
# action is: DiscoverNetworkServices 10.0.232.5 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.DiscoverNetworkServices.DiscoverNetworkServices'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# ===Perform the 3 step at CybORG level===
# action is: {'Blue': Monitor}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a259420>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a259c00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a2598a0>}
# action is: {'Blue': Monitor, 'Green': Sleep, 'Red': DiscoverNetworkServices 10.0.232.8}
# --> in actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in actions
# In simcontroller execute action
# action is: DiscoverNetworkServices 10.0.232.8 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.DiscoverNetworkServices.DiscoverNetworkServices'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# ===Perform the 4 step at CybORG level===
# action is: {'Blue': Monitor}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a259420>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a259c00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a2598a0>}
# action is: {'Blue': Monitor, 'Green': Sleep, 'Red': DiscoverNetworkServices 10.0.232.11}
# --> in actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in actions
# In simcontroller execute action
# action is: DiscoverNetworkServices 10.0.232.11 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.DiscoverNetworkServices.DiscoverNetworkServices'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# ===Perform the 5 step at CybORG level===
# action is: {'Blue': Monitor}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a259420>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a259c00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a2598a0>}
# action is: {'Blue': Monitor, 'Green': Sleep, 'Red': DiscoverNetworkServices 10.0.232.10}
# --> in actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in actions
# In simcontroller execute action
# action is: DiscoverNetworkServices 10.0.232.10 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.DiscoverNetworkServices.DiscoverNetworkServices'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# ===Perform the 6 step at CybORG level===
# action is: {'Blue': Monitor}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a259420>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a259c00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a2598a0>}
# action is: {'Blue': Monitor, 'Green': Sleep, 'Red': DiscoverNetworkServices 10.0.232.1}
# --> in actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in actions
# In simcontroller execute action
# action is: DiscoverNetworkServices 10.0.232.1 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.DiscoverNetworkServices.DiscoverNetworkServices'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# ===Perform the 7 step at CybORG level===
# action is: {'Blue': Monitor}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a259420>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a259c00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a2598a0>}
# action is: {'Blue': Monitor, 'Green': Sleep, 'Red': PrivilegeEscalate User0}
# --> in actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in actions
# In simcontroller execute action
# action is: PrivilegeEscalate User0 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.PrivilegeEscalate.PrivilegeEscalate'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# ===Perform the 8 step at CybORG level===
# action is: {'Blue': Monitor}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a259420>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a259c00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a2598a0>}
# action is: {'Blue': Monitor, 'Green': Sleep, 'Red': ExploitRemoteService 10.0.232.10}
# --> in actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in actions
# In simcontroller execute action
# action is: ExploitRemoteService 10.0.232.10 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.ExploitRemoteService.ExploitRemoteService'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# ===Perform the 9 step at CybORG level===
# action is: {'Blue': Remove User4}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a259420>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a259c00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a2598a0>}
# action is: {'Blue': Remove User4, 'Green': Sleep, 'Red': PrivilegeEscalate User4}
# --> in actions
# In simcontroller execute action
# action is: Remove User4 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Remove.Remove'>
# --> in actions
# In simcontroller execute action
# action is: PrivilegeEscalate User4 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.PrivilegeEscalate.PrivilegeEscalate'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# ===Perform the 10 step at CybORG level===
# action is: {'Blue': Monitor}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a259420>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a259c00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a2598a0>}
# action is: {'Blue': Monitor, 'Green': Sleep, 'Red': DiscoverNetworkServices 10.0.173.10}
# --> in actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in actions
# In simcontroller execute action
# action is: DiscoverNetworkServices 10.0.173.10 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.DiscoverNetworkServices.DiscoverNetworkServices'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# ===Perform the 11 step at CybORG level===
# action is: {'Blue': Monitor}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a259420>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a259c00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a2598a0>}
# action is: {'Blue': Monitor, 'Green': Sleep, 'Red': ExploitRemoteService 10.0.232.5}
# --> in actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in actions
# In simcontroller execute action
# action is: ExploitRemoteService 10.0.232.5 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.ExploitRemoteService.ExploitRemoteService'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# ===Perform the 12 step at CybORG level===
# action is: {'Blue': Remove User2}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a259420>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a259c00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a2598a0>}
# action is: {'Blue': Remove User2, 'Green': Sleep, 'Red': PrivilegeEscalate User2}
# --> in actions
# In simcontroller execute action
# action is: Remove User2 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Remove.Remove'>
# --> in actions
# In simcontroller execute action
# action is: PrivilegeEscalate User2 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.PrivilegeEscalate.PrivilegeEscalate'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# ===Perform the 13 step at CybORG level===
# action is: {'Blue': Monitor}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a259420>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a259c00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a2598a0>}
# action is: {'Blue': Monitor, 'Green': Sleep, 'Red': ExploitRemoteService 10.0.232.11}
# --> in actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in actions
# In simcontroller execute action
# action is: ExploitRemoteService 10.0.232.11 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.ExploitRemoteService.ExploitRemoteService'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# ===Perform the 14 step at CybORG level===
# action is: {'Blue': Monitor}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a259420>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a259c00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a2598a0>}
# action is: {'Blue': Monitor, 'Green': Sleep, 'Red': ExploitRemoteService 10.0.232.8}
# --> in actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in actions
# In simcontroller execute action
# action is: ExploitRemoteService 10.0.232.8 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.ExploitRemoteService.ExploitRemoteService'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# ===Perform the 15 step at CybORG level===
# action is: {'Blue': Monitor}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a259420>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a259c00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a2598a0>}
# action is: {'Blue': Monitor, 'Green': Sleep, 'Red': PrivilegeEscalate User4}
# --> in actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in actions
# In simcontroller execute action
# action is: PrivilegeEscalate User4 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.PrivilegeEscalate.PrivilegeEscalate'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# ===Perform the 16 step at CybORG level===
# action is: {'Blue': Monitor}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a259420>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a259c00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a2598a0>}
# action is: {'Blue': Monitor, 'Green': Sleep, 'Red': PrivilegeEscalate User0}
# --> in actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in actions
# In simcontroller execute action
# action is: PrivilegeEscalate User0 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.PrivilegeEscalate.PrivilegeEscalate'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# ===Perform the 17 step at CybORG level===
# action is: {'Blue': Monitor}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a259420>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a259c00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a2598a0>}
# action is: {'Blue': Monitor, 'Green': Sleep, 'Red': ExploitRemoteService 10.0.232.5}
# --> in actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in actions
# In simcontroller execute action
# action is: ExploitRemoteService 10.0.232.5 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.ExploitRemoteService.ExploitRemoteService'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# ===Perform the 18 step at CybORG level===
# action is: {'Blue': Monitor}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a259420>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a259c00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a2598a0>}
# action is: {'Blue': Monitor, 'Green': Sleep, 'Red': PrivilegeEscalate User2}
# --> in actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in actions
# In simcontroller execute action
# action is: PrivilegeEscalate User2 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.PrivilegeEscalate.PrivilegeEscalate'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# ===Perform the 19 step at CybORG level===
# action is: {'Blue': Monitor}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a259420>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a259c00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a2598a0>}
# action is: {'Blue': Monitor, 'Green': Sleep, 'Red': DiscoverNetworkServices 10.0.173.12}
# --> in actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in actions
# In simcontroller execute action
# action is: DiscoverNetworkServices 10.0.173.12 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.DiscoverNetworkServices.DiscoverNetworkServices'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# ===Perform the 20 step at CybORG level===
# action is: {'Blue': Monitor}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a259420>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a259c00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f618a2598a0>}
# action is: {'Blue': Monitor, 'Green': Sleep, 'Red': ExploitRemoteService 10.0.173.12}
# --> in actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in actions
# In simcontroller execute action
# action is: ExploitRemoteService 10.0.173.12 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.ExploitRemoteService.ExploitRemoteService'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations

# %%
# input('demo react restore')
agent = BlueReactRestoreAgent()
run_episode_cc2(cyborg, agent)
# Out:
# Agent Interfaces are: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbfa30>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbfac0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbdf00>}
# obs is {'success': <TrinaryEnum.UNKNOWN: 2>, 'Defender': {'Interface': [{'Interface Name': 'eth0', 'IP Address': IPv4Address('10.0.250.167'), 'Subnet': IPv4Network('10.0.250.160/28')}], 'Sessions': [{'Username': 'ubuntu', 'ID': 0, 'Timeout': 0, 'PID': 2292, 'Type': <SessionType.VELOCIRAPTOR_SERVER: 8>, 'Agent': 'Blue'}, {'Username': 'ubuntu', 'ID': 9, 'Timeout': 0, 'PID': 2296, 'Type': <SessionType.VELOCIRAPTOR_CLIENT: 7>, 'Agent': 'Blue'}], 'Processes': [{'PID': 2292, 'Username': 'ubuntu'}, {'PID': 2296, 'Username': 'ubuntu'}], 'User Info': [{'Username': 'root', 'Groups': [{'GID': 0}]}, {'Username': 'ubuntu', 'Groups': [{'GID': 1000}]}], 'System info': {'Hostname': 'Defender', 'OSType': <OperatingSystemType.LINUX: 3>, 'OSDistribution': <OperatingSystemDistribution.UBUNTU: 8>, 'OSVersion': <OperatingSystemVersion.U18_04_3: 6>, 'Architecture': <Architecture.x64: 2>, 'position': (63, 45)}}, 'Enterprise0': {'Interface': [{'Interface Name': 'eth0', 'IP Address': IPv4Address('10.0.250.169'), 'Subnet': IPv4Network('10.0.250.160/28')}], 'Sessions': [{'Username': 'ubuntu', 'ID': 6, 'Timeout': 0, 'PID': 1097, 'Type': <SessionType.VELOCIRAPTOR_CLIENT: 7>, 'Agent': 'Blue'}], 'Processes': [{'PID': 1097, 'Username': 'ubuntu'}], 'User Info': [{'Username': 'root', 'Groups': [{'GID': 0}]}, {'Username': 'www-data', 'Groups': [{'GID': 33}]}, {'Username': 'pi', 'Password': 'raspberry', 'Groups': [{'GID': 1001}]}, {'Username': 'ubuntu', 'Groups': [{'GID': 1000}]}, {'Username': 'GreenAgent', 'Groups': [{'GID': 1001}]}], 'System info': {'Hostname': 'Enterprise0', 'OSType': <OperatingSystemType.LINUX: 3>, 'OSDistribution': <OperatingSystemDistribution.UBUNTU: 8>, 'OSVersion': <OperatingSystemVersion.U18_04_3: 6>, 'Architecture': <Architecture.x64: 2>, 'position': (30, 55)}}, 'Enterprise1': {'Interface': [{'Interface Name': 'eth0', 'IP Address': IPv4Address('10.0.250.166'), 'Subnet': IPv4Network('10.0.250.160/28')}], 'Sessions': [{'Username': 'SYSTEM', 'ID': 7, 'Timeout': 0, 'PID': 4403, 'Type': <SessionType.VELOCIRAPTOR_CLIENT: 7>, 'Agent': 'Blue'}], 'Processes': [{'PID': 4403, 'Username': 'SYSTEM'}], 'User Info': [{'Username': 'Administrator', 'Groups': [{'GID': 0}]}, {'Username': 'GreenAgent'}, {'Username': 'vagrant', 'Password': 'vagrant', 'Groups': [{'GID': 0}]}, {'Username': 'SYSTEM'}], 'System info': {'Hostname': 'Enterprise1', 'OSType': <OperatingSystemType.WINDOWS: 2>, 'OSDistribution': <OperatingSystemDistribution.WINDOWS_SVR_2008: 4>, 'OSVersion': <OperatingSystemVersion.W6_1_7601: 13>, 'Architecture': <Architecture.x64: 2>, 'position': (30, 45)}}, 'Enterprise2': {'Interface': [{'Interface Name': 'eth0', 'IP Address': IPv4Address('10.0.250.171'), 'Subnet': IPv4Network('10.0.250.160/28')}], 'Sessions': [{'Username': 'SYSTEM', 'ID': 8, 'Timeout': 0, 'PID': 4407, 'Type': <SessionType.VELOCIRAPTOR_CLIENT: 7>, 'Agent': 'Blue'}], 'Processes': [{'PID': 4407, 'Username': 'SYSTEM'}], 'User Info': [{'Username': 'Administrator', 'Groups': [{'GID': 0}]}, {'Username': 'GreenAgent'}, {'Username': 'vagrant', 'Password': 'vagrant', 'Groups': [{'GID': 0}]}, {'Username': 'SYSTEM'}], 'System info': {'Hostname': 'Enterprise2', 'OSType': <OperatingSystemType.WINDOWS: 2>, 'OSDistribution': <OperatingSystemDistribution.WINDOWS_SVR_2008: 4>, 'OSVersion': <OperatingSystemVersion.W6_1_7601: 13>, 'Architecture': <Architecture.x64: 2>, 'position': (63, 55)}}, 'Op_Host0': {'Interface': [{'Interface Name': 'eth0', 'IP Address': IPv4Address('10.0.161.196'), 'Subnet': IPv4Network('10.0.161.192/28')}], 'Sessions': [{'Username': 'ubuntu', 'ID': 11, 'Timeout': 0, 'PID': 1094, 'Type': <SessionType.VELOCIRAPTOR_CLIENT: 7>, 'Agent': 'Blue'}], 'Processes': [{'PID': 1094, 'Username': 'ubuntu'}], 'User Info': [{'Username': 'root', 'Groups': [{'GID': 0}]}, {'Username': 'www-data', 'Groups': [{'GID': 33}]}, {'Username': 'pi', 'Password': 'raspberry', 'Groups': [{'GID': 1001}]}, {'Username': 'ubuntu', 'Groups': [{'GID': 1000}]}, {'Username': 'GreenAgent', 'Groups': [{'GID': 1001}]}] ...
# ===Perform the 1 step at CybORG level===
# action is: {'Blue': Monitor}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbfa30>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbfac0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbdf00>}
# action is: {'Blue': Monitor, 'Green': Sleep, 'Red': DiscoverRemoteSystems 10.0.225.64/28}
# --> in actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in actions
# In simcontroller execute action
# action is: DiscoverRemoteSystems 10.0.225.64/28 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.DiscoverRemoteSystems.DiscoverRemoteSystems'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# obs is {'success': <TrinaryEnum.TRUE: 1>}
# ===Perform the 2 step at CybORG level===
# action is: {'Blue': Monitor}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbfa30>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbfac0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbdf00>}
# action is: {'Blue': Monitor, 'Green': Sleep, 'Red': DiscoverNetworkServices 10.0.225.66}
# --> in actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in actions
# In simcontroller execute action
# action is: DiscoverNetworkServices 10.0.225.66 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.DiscoverNetworkServices.DiscoverNetworkServices'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# obs is {'success': <TrinaryEnum.TRUE: 1>, 'User4': {'System info': {'Hostname': 'User4', 'OSType': <OperatingSystemType.LINUX: 3>, 'OSDistribution': <OperatingSystemDistribution.UBUNTU: 8>, 'OSVersion': <OperatingSystemVersion.U18_04_3: 6>, 'Architecture': <Architecture.x64: 2>, 'position': (63, 30)}, 'Processes': [{'Connections': [{'local_port': 22, 'remote_port': 50518, 'local_address': IPv4Address('10.0.225.66'), 'remote_address': IPv4Address('10.0.225.78')}]}, {'Connections': [{'local_port': 80, 'remote_port': 51825, 'local_address': IPv4Address('10.0.225.66'), 'remote_address': IPv4Address('10.0.225.78')}]}, {'Connections': [{'local_port': 3390, 'remote_port': 57404, 'local_address': IPv4Address('10.0.225.66'), 'remote_address': IPv4Address('10.0.225.78')}]}, {'Connections': [{'local_port': 443, 'remote_port': 59344, 'local_address': IPv4Address('10.0.225.66'), 'remote_address': IPv4Address('10.0.225.78')}]}, {'Connections': [{'local_port': 25, 'remote_port': 56096, 'local_address': IPv4Address('10.0.225.66'), 'remote_address': IPv4Address('10.0.225.78')}]}], 'Interface': [{'IP Address': IPv4Address('10.0.225.66')}]}}
# ===Perform the 3 step at CybORG level===
# action is: {'Blue': Monitor}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbfa30>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbfac0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbdf00>}
# action is: {'Blue': Monitor, 'Green': Sleep, 'Red': DiscoverNetworkServices 10.0.225.65}
# --> in actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in actions
# In simcontroller execute action
# action is: DiscoverNetworkServices 10.0.225.65 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.DiscoverNetworkServices.DiscoverNetworkServices'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# obs is {'success': <TrinaryEnum.TRUE: 1>, 'User3': {'System info': {'Hostname': 'User3', 'OSType': <OperatingSystemType.LINUX: 3>, 'OSDistribution': <OperatingSystemDistribution.UBUNTU: 8>, 'OSVersion': <OperatingSystemVersion.U18_04_3: 6>, 'Architecture': <Architecture.x64: 2>, 'position': (60, 20)}, 'Processes': [{'Connections': [{'local_port': 80, 'remote_port': 55140, 'local_address': IPv4Address('10.0.225.65'), 'remote_address': IPv4Address('10.0.225.78')}]}, {'Connections': [{'local_port': 3389, 'remote_port': 51904, 'local_address': IPv4Address('10.0.225.65'), 'remote_address': IPv4Address('10.0.225.78')}]}, {'Connections': [{'local_port': 443, 'remote_port': 49635, 'local_address': IPv4Address('10.0.225.65'), 'remote_address': IPv4Address('10.0.225.78')}]}, {'Connections': [{'local_port': 25, 'remote_port': 49764, 'local_address': IPv4Address('10.0.225.65'), 'remote_address': IPv4Address('10.0.225.78')}]}], 'Interface': [{'IP Address': IPv4Address('10.0.225.65')}]}}
# ===Perform the 4 step at CybORG level===
# action is: {'Blue': Monitor}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbfa30>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbfac0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbdf00>}
# action is: {'Blue': Monitor, 'Green': Sleep, 'Red': DiscoverNetworkServices 10.0.225.78}
# --> in actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in actions
# In simcontroller execute action
# action is: DiscoverNetworkServices 10.0.225.78 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.DiscoverNetworkServices.DiscoverNetworkServices'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# obs is {'success': <TrinaryEnum.TRUE: 1>, 'User0': {'System info': {'Hostname': 'User0', 'OSType': <OperatingSystemType.WINDOWS: 2>, 'OSDistribution': <OperatingSystemDistribution.WINDOWS_SVR_2008: 4>, 'OSVersion': <OperatingSystemVersion.W6_1_7601: 13>, 'Architecture': <Architecture.x64: 2>, 'position': (28, 30)}, 'Processes': [{'Connections': [{'local_port': 22, 'remote_port': 51364, 'local_address': IPv4Address('10.0.225.78'), 'remote_address': IPv4Address('10.0.225.78')}]}, {'Connections': [{'local_port': 21, 'remote_port': 59668, 'local_address': IPv4Address('10.0.225.78'), 'remote_address': IPv4Address('10.0.225.78')}]}], 'Interface': [{'IP Address': IPv4Address('10.0.225.78')}]}}
# ===Perform the 5 step at CybORG level===
# action is: {'Blue': Monitor}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbfa30>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbfac0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbdf00>}
# action is: {'Blue': Monitor, 'Green': Sleep, 'Red': DiscoverNetworkServices 10.0.225.67}
# --> in actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in actions
# In simcontroller execute action
# action is: DiscoverNetworkServices 10.0.225.67 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.DiscoverNetworkServices.DiscoverNetworkServices'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# obs is {'success': <TrinaryEnum.TRUE: 1>, 'User1': {'System info': {'Hostname': 'User1', 'OSType': <OperatingSystemType.WINDOWS: 2>, 'OSDistribution': <OperatingSystemDistribution.WINDOWS_SVR_2008: 4>, 'OSVersion': <OperatingSystemVersion.W6_1_7601: 13>, 'Architecture': <Architecture.x64: 2>, 'position': (31, 20)}, 'Processes': [{'Connections': [{'local_port': 22, 'remote_port': 54368, 'local_address': IPv4Address('10.0.225.67'), 'remote_address': IPv4Address('10.0.225.78')}]}, {'Connections': [{'local_port': 21, 'remote_port': 55703, 'local_address': IPv4Address('10.0.225.67'), 'remote_address': IPv4Address('10.0.225.78')}]}], 'Interface': [{'IP Address': IPv4Address('10.0.225.67')}]}}
# ===Perform the 6 step at CybORG level===
# action is: {'Blue': Monitor}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbfa30>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbfac0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbdf00>}
# action is: {'Blue': Monitor, 'Green': Sleep, 'Red': DiscoverNetworkServices 10.0.225.74}
# --> in actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in actions
# In simcontroller execute action
# action is: DiscoverNetworkServices 10.0.225.74 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.DiscoverNetworkServices.DiscoverNetworkServices'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# obs is {'success': <TrinaryEnum.TRUE: 1>, 'User2': {'System info': {'Hostname': 'User2', 'OSType': <OperatingSystemType.WINDOWS: 2>, 'OSDistribution': <OperatingSystemDistribution.WINDOWS_SVR_2008: 4>, 'OSVersion': <OperatingSystemVersion.W6_1_7601: 13>, 'Architecture': <Architecture.x64: 2>, 'position': (45, 15)}, 'Processes': [{'Connections': [{'local_port': 445, 'remote_port': 55138, 'local_address': IPv4Address('10.0.225.74'), 'remote_address': IPv4Address('10.0.225.78')}]}, {'Connections': [{'local_port': 139, 'remote_port': 53601, 'local_address': IPv4Address('10.0.225.74'), 'remote_address': IPv4Address('10.0.225.78')}]}, {'Connections': [{'local_port': 135, 'remote_port': 55764, 'local_address': IPv4Address('10.0.225.74'), 'remote_address': IPv4Address('10.0.225.78')}]}, {'Connections': [{'local_port': 3389, 'remote_port': 50375, 'local_address': IPv4Address('10.0.225.74'), 'remote_address': IPv4Address('10.0.225.78')}]}], 'Interface': [{'IP Address': IPv4Address('10.0.225.74')}]}}
# ===Perform the 7 step at CybORG level===
# action is: {'Blue': Monitor}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbfa30>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbfac0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbdf00>}
# action is: {'Blue': Monitor, 'Green': Sleep, 'Red': PrivilegeEscalate User0}
# --> in actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in actions
# In simcontroller execute action
# action is: PrivilegeEscalate User0 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.PrivilegeEscalate.PrivilegeEscalate'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# obs is {'success': <TrinaryEnum.TRUE: 1>}
# ===Perform the 8 step at CybORG level===
# action is: {'Blue': Monitor}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbfa30>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbfac0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbdf00>}
# action is: {'Blue': Monitor, 'Green': Sleep, 'Red': ExploitRemoteService 10.0.225.78}
# --> in actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in actions
# In simcontroller execute action
# action is: ExploitRemoteService 10.0.225.78 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.ExploitRemoteService.ExploitRemoteService'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# obs is {'success': <TrinaryEnum.TRUE: 1>, 'User0': {'System info': {'Hostname': 'User0', 'OSType': <OperatingSystemType.WINDOWS: 2>, 'OSDistribution': <OperatingSystemDistribution.WINDOWS_SVR_2008: 4>, 'OSVersion': <OperatingSystemVersion.W6_1_7601: 13>, 'Architecture': <Architecture.x64: 2>, 'position': (28, 30)}, 'Processes': [{'Connections': [{'local_port': 22, 'remote_port': 50062, 'local_address': IPv4Address('10.0.225.78'), 'remote_address': IPv4Address('10.0.225.78')}]}, {'Connections': [{'local_port': 22, 'remote_port': 50816, 'local_address': IPv4Address('10.0.225.78'), 'remote_address': IPv4Address('10.0.225.78')}]}, {'Connections': [{'local_port': 22, 'remote_port': 50816, 'local_address': IPv4Address('10.0.225.78'), 'remote_address': IPv4Address('10.0.225.78')}]}, {'Connections': [{'local_port': 22, 'remote_port': 50816, 'local_address': IPv4Address('10.0.225.78'), 'remote_address': IPv4Address('10.0.225.78')}]}, {'Connections': [{'local_port': 22, 'remote_port': 50816, 'local_address': IPv4Address('10.0.225.78'), 'remote_address': IPv4Address('10.0.225.78')}]}, {'Connections': [{'local_port': 22, 'remote_port': 50816, 'local_address': IPv4Address('10.0.225.78'), 'remote_address': IPv4Address('10.0.225.78')}]}, {'Connections': [{'local_port': 22, 'remote_port': 50816, 'local_address': IPv4Address('10.0.225.78'), 'remote_address': IPv4Address('10.0.225.78')}]}, {'Connections': [{'local_port': 22, 'remote_port': 50816, 'local_address': IPv4Address('10.0.225.78'), 'remote_address': IPv4Address('10.0.225.78')}]}, {'Connections': [{'local_port': 22, 'remote_port': 50816, 'local_address': IPv4Address('10.0.225.78'), 'remote_address': IPv4Address('10.0.225.78')}]}, {'Connections': [{'local_port': 22, 'remote_port': 50816, 'local_address': IPv4Address('10.0.225.78'), 'remote_address': IPv4Address('10.0.225.78')}]}, {'Connections': [{'local_port': 22, 'remote_port': 50816, 'local_address': IPv4Address('10.0.225.78'), 'remote_address': IPv4Address('10.0.225.78')}]}, {'PID': 3380}], 'Interface': [{'IP Address': IPv4Address('10.0.225.78')}]}}
# ===Perform the 9 step at CybORG level===
# action is: {'Blue': Monitor}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbfa30>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbfac0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbdf00>}
# action is: {'Blue': Monitor, 'Green': Sleep, 'Red': ExploitRemoteService 10.0.225.67}
# --> in actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in actions
# In simcontroller execute action
# action is: ExploitRemoteService 10.0.225.67 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.ExploitRemoteService.ExploitRemoteService'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# obs is {'success': <TrinaryEnum.TRUE: 1>, 'User1': {'System info': {'Hostname': 'User1', 'OSType': <OperatingSystemType.WINDOWS: 2>, 'OSDistribution': <OperatingSystemDistribution.WINDOWS_SVR_2008: 4>, 'OSVersion': <OperatingSystemVersion.W6_1_7601: 13>, 'Architecture': <Architecture.x64: 2>, 'position': (31, 20)}, 'Processes': [{'Connections': [{'local_port': 22, 'remote_port': 53457, 'local_address': IPv4Address('10.0.225.67'), 'remote_address': IPv4Address('10.0.225.78')}]}, {'Connections': [{'local_port': 22, 'remote_port': 53366, 'local_address': IPv4Address('10.0.225.67'), 'remote_address': IPv4Address('10.0.225.78')}]}, {'Connections': [{'local_port': 22, 'remote_port': 53366, 'local_address': IPv4Address('10.0.225.67'), 'remote_address': IPv4Address('10.0.225.78')}]}, {'Connections': [{'local_port': 22, 'remote_port': 53366, 'local_address': IPv4Address('10.0.225.67'), 'remote_address': IPv4Address('10.0.225.78')}]}, {'Connections': [{'local_port': 22, 'remote_port': 53366, 'local_address': IPv4Address('10.0.225.67'), 'remote_address': IPv4Address('10.0.225.78')}]}, {'Connections': [{'local_port': 22, 'remote_port': 53366, 'local_address': IPv4Address('10.0.225.67'), 'remote_address': IPv4Address('10.0.225.78')}]}, {'Connections': [{'local_port': 22, 'remote_port': 53366, 'local_address': IPv4Address('10.0.225.67'), 'remote_address': IPv4Address('10.0.225.78')}]}, {'Connections': [{'local_port': 22, 'remote_port': 53366, 'local_address': IPv4Address('10.0.225.67'), 'remote_address': IPv4Address('10.0.225.78')}]}, {'Connections': [{'local_port': 22, 'remote_port': 53366, 'local_address': IPv4Address('10.0.225.67'), 'remote_address': IPv4Address('10.0.225.78')}]}, {'Connections': [{'local_port': 22, 'remote_port': 53366, 'local_address': IPv4Address('10.0.225.67'), 'remote_address': IPv4Address('10.0.225.78')}]}, {'Connections': [{'local_port': 22, 'remote_port': 53366, 'local_address': IPv4Address('10.0.225.67'), 'remote_address': IPv4Address('10.0.225.78')}]}, {'PID': 3381}], 'Interface': [{'IP Address': IPv4Address('10.0.225.67')}]}}
# ===Perform the 10 step at CybORG level===
# action is: {'Blue': Restore User1}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbfa30>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbfac0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbdf00>}
# action is: {'Blue': Restore User1, 'Green': Sleep, 'Red': PrivilegeEscalate User1}
# --> in actions
# In simcontroller execute action
# action is: Restore User1 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Restore.Restore'>
# --> in actions
# In simcontroller execute action
# action is: PrivilegeEscalate User1 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.PrivilegeEscalate.PrivilegeEscalate'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# obs is {'success': <TrinaryEnum.TRUE: 1>}
# ===Perform the 11 step at CybORG level===
# action is: {'Blue': Monitor}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbfa30>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbfac0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbdf00>}
# action is: {'Blue': Monitor, 'Green': Sleep, 'Red': ExploitRemoteService 10.0.225.66}
# --> in actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in actions
# In simcontroller execute action
# action is: ExploitRemoteService 10.0.225.66 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.ExploitRemoteService.ExploitRemoteService'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# obs is {'success': <TrinaryEnum.TRUE: 1>, 'User0': {'System info': {'Hostname': 'User0', 'OSType': <OperatingSystemType.WINDOWS: 2>, 'OSDistribution': <OperatingSystemDistribution.WINDOWS_SVR_2008: 4>, 'OSVersion': <OperatingSystemVersion.W6_1_7601: 13>, 'Architecture': <Architecture.x64: 2>, 'position': (28, 30)}, 'Processes': [{'Connections': [{'remote_port': 3390, 'local_address': IPv4Address('10.0.225.66'), 'remote_address': IPv4Address('10.0.225.78')}]}], 'Interface': [{'IP Address': IPv4Address('10.0.225.66')}]}, 'User4': {'System info': {'Hostname': 'User4', 'OSType': <OperatingSystemType.LINUX: 3>, 'OSDistribution': <OperatingSystemDistribution.UBUNTU: 8>, 'OSVersion': <OperatingSystemVersion.U18_04_3: 6>, 'Architecture': <Architecture.x64: 2>, 'position': (63, 30)}, 'Processes': [{'Connections': [{'remote_port': 3390, 'local_address': IPv4Address('10.0.225.66'), 'remote_address': IPv4Address('10.0.225.78')}]}, {'Connections': [{'local_port': 3390, 'remote_port': 57619, 'local_address': IPv4Address('10.0.225.66'), 'remote_address': IPv4Address('10.0.225.78')}]}], 'Interface': [{'IP Address': IPv4Address('10.0.225.66')}]}}
# ===Perform the 12 step at CybORG level===
# action is: {'Blue': Monitor}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbfa30>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbfac0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbdf00>}
# action is: {'Blue': Monitor, 'Green': Sleep, 'Red': PrivilegeEscalate User4}
# --> in actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in actions
# In simcontroller execute action
# action is: PrivilegeEscalate User4 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.PrivilegeEscalate.PrivilegeEscalate'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# obs is {'success': <TrinaryEnum.TRUE: 1>}
# ===Perform the 13 step at CybORG level===
# action is: {'Blue': Monitor}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbfa30>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbfac0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbdf00>}
# action is: {'Blue': Monitor, 'Green': Sleep, 'Red': DiscoverNetworkServices 10.0.250.169}
# --> in actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in actions
# In simcontroller execute action
# action is: DiscoverNetworkServices 10.0.250.169 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.DiscoverNetworkServices.DiscoverNetworkServices'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# obs is {'success': <TrinaryEnum.TRUE: 1>, 'Enterprise0': {'System info': {'Hostname': 'Enterprise0', 'OSType': <OperatingSystemType.LINUX: 3>, 'OSDistribution': <OperatingSystemDistribution.UBUNTU: 8>, 'OSVersion': <OperatingSystemVersion.U18_04_3: 6>, 'Architecture': <Architecture.x64: 2>, 'position': (30, 55)}, 'Processes': [{'Connections': [{'local_port': 22, 'remote_port': 52646, 'local_address': IPv4Address('10.0.250.169'), 'remote_address': IPv4Address('10.0.225.78')}]}], 'Interface': [{'IP Address': IPv4Address('10.0.250.169')}]}}
# ===Perform the 14 step at CybORG level===
# action is: {'Blue': Monitor}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbfa30>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbfac0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbdf00>}
# action is: {'Blue': Monitor, 'Green': Sleep, 'Red': ExploitRemoteService 10.0.225.74}
# --> in actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in actions
# In simcontroller execute action
# action is: ExploitRemoteService 10.0.225.74 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.ExploitRemoteService.ExploitRemoteService'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# obs is {'success': <TrinaryEnum.TRUE: 1>, 'User0': {'System info': {'Hostname': 'User0', 'OSType': <OperatingSystemType.WINDOWS: 2>, 'OSDistribution': <OperatingSystemDistribution.WINDOWS_SVR_2008: 4>, 'OSVersion': <OperatingSystemVersion.W6_1_7601: 13>, 'Architecture': <Architecture.x64: 2>, 'position': (28, 30)}, 'Processes': [{'Connections': [{'remote_port': 3389, 'local_address': IPv4Address('10.0.225.74'), 'remote_address': IPv4Address('10.0.225.78')}]}], 'Interface': [{'IP Address': IPv4Address('10.0.225.74')}]}, 'User2': {'System info': {'Hostname': 'User2', 'OSType': <OperatingSystemType.WINDOWS: 2>, 'OSDistribution': <OperatingSystemDistribution.WINDOWS_SVR_2008: 4>, 'OSVersion': <OperatingSystemVersion.W6_1_7601: 13>, 'Architecture': <Architecture.x64: 2>, 'position': (45, 15)}, 'Processes': [{'Connections': [{'remote_port': 3389, 'local_address': IPv4Address('10.0.225.74'), 'remote_address': IPv4Address('10.0.225.78')}]}, {'Connections': [{'local_port': 3389, 'remote_port': 50107, 'local_address': IPv4Address('10.0.225.74'), 'remote_address': IPv4Address('10.0.225.78')}]}, {'PID': 4421}], 'Interface': [{'IP Address': IPv4Address('10.0.225.74')}]}}
# ===Perform the 15 step at CybORG level===
# action is: {'Blue': Restore User2}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbfa30>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbfac0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbdf00>}
# action is: {'Blue': Restore User2, 'Green': Sleep, 'Red': PrivilegeEscalate User2}
# --> in actions
# In simcontroller execute action
# action is: Restore User2 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Restore.Restore'>
# --> in actions
# In simcontroller execute action
# action is: PrivilegeEscalate User2 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.PrivilegeEscalate.PrivilegeEscalate'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# obs is {'success': <TrinaryEnum.TRUE: 1>}
# ===Perform the 16 step at CybORG level===
# action is: {'Blue': Monitor}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbfa30>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbfac0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbdf00>}
# action is: {'Blue': Monitor, 'Green': Sleep, 'Red': ExploitRemoteService 10.0.225.74}
# --> in actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in actions
# In simcontroller execute action
# action is: ExploitRemoteService 10.0.225.74 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.ExploitRemoteService.ExploitRemoteService'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# obs is {'success': <TrinaryEnum.TRUE: 1>, 'User0': {'System info': {'Hostname': 'User0', 'OSType': <OperatingSystemType.WINDOWS: 2>, 'OSDistribution': <OperatingSystemDistribution.WINDOWS_SVR_2008: 4>, 'OSVersion': <OperatingSystemVersion.W6_1_7601: 13>, 'Architecture': <Architecture.x64: 2>, 'position': (28, 30)}, 'Processes': [{'Connections': [{'remote_port': 3389, 'local_address': IPv4Address('10.0.225.74'), 'remote_address': IPv4Address('10.0.225.78')}]}], 'Interface': [{'IP Address': IPv4Address('10.0.225.74')}]}, 'User2': {'System info': {'Hostname': 'User2', 'OSType': <OperatingSystemType.WINDOWS: 2>, 'OSDistribution': <OperatingSystemDistribution.WINDOWS_SVR_2008: 4>, 'OSVersion': <OperatingSystemVersion.W6_1_7601: 13>, 'Architecture': <Architecture.x64: 2>, 'position': (45, 15)}, 'Processes': [{'Connections': [{'remote_port': 3389, 'local_address': IPv4Address('10.0.225.74'), 'remote_address': IPv4Address('10.0.225.78')}]}, {'Connections': [{'local_port': 3389, 'remote_port': 58154, 'local_address': IPv4Address('10.0.225.74'), 'remote_address': IPv4Address('10.0.225.78')}]}, {'PID': 4426}], 'Interface': [{'IP Address': IPv4Address('10.0.225.74')}]}}
# ===Perform the 17 step at CybORG level===
# action is: {'Blue': Restore User2}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbfa30>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbfac0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbdf00>}
# action is: {'Blue': Restore User2, 'Green': Sleep, 'Red': PrivilegeEscalate User2}
# --> in actions
# In simcontroller execute action
# action is: Restore User2 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Restore.Restore'>
# --> in actions
# In simcontroller execute action
# action is: PrivilegeEscalate User2 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.PrivilegeEscalate.PrivilegeEscalate'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# obs is {'success': <TrinaryEnum.TRUE: 1>}
# ===Perform the 18 step at CybORG level===
# action is: {'Blue': Monitor}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbfa30>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbfac0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbdf00>}
# action is: {'Blue': Monitor, 'Green': Sleep, 'Red': ExploitRemoteService 10.0.225.74}
# --> in actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in actions
# In simcontroller execute action
# action is: ExploitRemoteService 10.0.225.74 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.ExploitRemoteService.ExploitRemoteService'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# obs is {'success': <TrinaryEnum.TRUE: 1>, 'User0': {'System info': {'Hostname': 'User0', 'OSType': <OperatingSystemType.WINDOWS: 2>, 'OSDistribution': <OperatingSystemDistribution.WINDOWS_SVR_2008: 4>, 'OSVersion': <OperatingSystemVersion.W6_1_7601: 13>, 'Architecture': <Architecture.x64: 2>, 'position': (28, 30)}, 'Processes': [{'Connections': [{'remote_port': 3389, 'local_address': IPv4Address('10.0.225.74'), 'remote_address': IPv4Address('10.0.225.78')}]}], 'Interface': [{'IP Address': IPv4Address('10.0.225.74')}]}, 'User2': {'System info': {'Hostname': 'User2', 'OSType': <OperatingSystemType.WINDOWS: 2>, 'OSDistribution': <OperatingSystemDistribution.WINDOWS_SVR_2008: 4>, 'OSVersion': <OperatingSystemVersion.W6_1_7601: 13>, 'Architecture': <Architecture.x64: 2>, 'position': (45, 15)}, 'Processes': [{'Connections': [{'local_port': 3389, 'remote_port': 59876, 'local_address': IPv4Address('10.0.225.74'), 'remote_address': IPv4Address('10.0.225.78')}]}, {'PID': 4419}], 'Interface': [{'IP Address': IPv4Address('10.0.225.74')}]}}
# ===Perform the 19 step at CybORG level===
# action is: {'Blue': Restore User2}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbfa30>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbfac0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbdf00>}
# action is: {'Blue': Restore User2, 'Green': Sleep, 'Red': PrivilegeEscalate User2}
# --> in actions
# In simcontroller execute action
# action is: Restore User2 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Restore.Restore'>
# --> in actions
# In simcontroller execute action
# action is: PrivilegeEscalate User2 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.PrivilegeEscalate.PrivilegeEscalate'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# obs is {'success': <TrinaryEnum.TRUE: 1>}
# ===Perform the 20 step at CybORG level===
# action is: {'Blue': Monitor}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbfa30>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbfac0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dbdf00>}
# action is: {'Blue': Monitor, 'Green': Sleep, 'Red': ExploitRemoteService 10.0.225.67}
# --> in actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in actions
# In simcontroller execute action
# action is: ExploitRemoteService 10.0.225.67 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.ExploitRemoteService.ExploitRemoteService'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations

# %% [markdown]
# ## Training

# %%
MAX_STEPS_PER_GAME = 20
MAX_EPS = 20

# %%
def run_training_example_rb(scenario):
    agent_name = 'Red'
    path = str(inspect.getfile(CybORG))
    path = path[:-7] + f'/Simulator/Scenarios/scenario_files/{scenario}.yaml'
    sg = FileReaderScenarioGenerator(path)
    cyborg = CybORG(scenario_generator=sg)
    cyborg = OpenAIGymWrapper(agent_name=agent_name,
                              env=FixedFlatWrapper(cyborg))

    observation = cyborg.reset()
    action_space = cyborg.action_space
    print(f"Observation size {len(observation)}, Action Size {action_space}")
    action_count = 0
    agent = RandomAgent()
    print(agent)
    agent.set_initial_values(action_space, observation)
    for i in range(MAX_EPS):  # laying multiple games
        print(f"\rTraining Game: {i}\n", end='', flush=True)
        reward = 0
        for j in range(MAX_STEPS_PER_GAME):  # step in 1 game
            action = agent.get_action(observation, action_space)
            print(f"Action is {action} for {agent}")
            next_observation, r, done, info = cyborg.step(action)

            action_space = cyborg.action_space
            reward += r

            agent.train(observation)  # training the agent
            observation = next_observation
            if done or j == MAX_STEPS_PER_GAME - 1:
                print(f"Training reward: {reward}")
                break
        agent.end_episode()
        observation = cyborg.reset()
        action_space = cyborg.action_space
        agent.set_initial_values(action_space, observation)

# %%
run_training_example_rb('Scenario2')
# Out:
# env is: sim
# Agent Interfaces are: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c13970>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c111e0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c13be0>}
# Agent Interfaces are: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53c10>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53d00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53070>}
# Observation size 11293, Action Size Discrete(212)
# RandomAgent
# Training Game: 0
# Action is 34 for RandomAgent
# action is: {'Red': ExploitRemoteService 10.0.103.246}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53c10>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53d00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53070>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 87 for RandomAgent
# action is: {'Red': HarakaRCE}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53c10>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53d00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53070>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 129 for RandomAgent
# action is: {'Red': HTTPSRFI}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53c10>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53d00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53070>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 92 for RandomAgent
# action is: {'Red': HarakaRCE}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53c10>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53d00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53070>}
# action is: {'Red': HarakaRCE, 'Blue': Sleep, 'Green': Sleep}
# --> in actions
# In simcontroller execute action
# action is: HarakaRCE its type is: <class 'CybORG.Simulator.Actions.ConcreteActions.ExploitActions.HarakaRCE.HarakaRCE'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# Action is 136 for RandomAgent
# action is: {'Red': SQLInjection}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53c10>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53d00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53070>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 28 for RandomAgent
# action is: {'Red': ExploitRemoteService 10.0.106.231}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53c10>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53d00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53070>}
# action is: {'Red': ExploitRemoteService 10.0.106.231, 'Blue': Sleep, 'Green': Sleep}
# --> in actions
# In simcontroller execute action
# action is: ExploitRemoteService 10.0.106.231 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.ExploitRemoteService.ExploitRemoteService'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# Action is 61 for RandomAgent
# action is: {'Red': EternalBlue}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53c10>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53d00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53070>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 181 for RandomAgent
# action is: {'Red': Impact Enterprise0}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53c10>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53d00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53070>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 170 for RandomAgent
# action is: {'Red': PrivilegeEscalate Op_Host2}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53c10>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53d00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53070>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 206 for RandomAgent
# action is: {'Red': SSHBruteForce}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53c10>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53d00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53070>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 177 for RandomAgent
# action is: {'Red': PrivilegeEscalate Enterprise_router}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53c10>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53d00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53070>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 104 for RandomAgent
# action is: {'Red': HTTPRFI}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53c10>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53d00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53070>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 119 for RandomAgent
# action is: {'Red': HTTPSRFI}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53c10>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53d00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53070>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 207 for RandomAgent
# action is: {'Red': SSHBruteForce}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53c10>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53d00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53070>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 179 for RandomAgent
# action is: {'Red': PrivilegeEscalate User_router}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53c10>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53d00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53070>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 128 for RandomAgent
# action is: {'Red': HTTPSRFI}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53c10>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53d00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53070>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 80 for RandomAgent
# action is: {'Red': FTPDirectoryTraversal}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53c10>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53d00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53070>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 75 for RandomAgent
# action is: {'Red': FTPDirectoryTraversal}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53c10>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53d00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53070>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 139 for RandomAgent
# action is: {'Red': SQLInjection}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53c10>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53d00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53070>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 125 for RandomAgent
# action is: {'Red': HTTPSRFI}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53c10>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53d00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53070>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Training reward: 0.0
# Agent Interfaces are: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f66b79c7e20>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dedc00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680def580>}
# Training Game: 1
# Action is 172 for RandomAgent
# action is: {'Red': PrivilegeEscalate User0}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f66b79c7e20>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dedc00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680def580>}
# action is: {'Red': PrivilegeEscalate User0, 'Blue': Sleep, 'Green': Sleep}
# --> in actions
# In simcontroller execute action
# action is: PrivilegeEscalate User0 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.PrivilegeEscalate.PrivilegeEscalate'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# Action is 25 for RandomAgent
# action is: {'Red': ExploitRemoteService 10.0.70.97}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f66b79c7e20>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dedc00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680def580>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 191 for RandomAgent
# action is: {'Red': Impact User3}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f66b79c7e20>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dedc00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680def580>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 147 for RandomAgent
# action is: {'Red': SQLInjection}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f66b79c7e20>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dedc00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680def580>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 21 for RandomAgent
# action is: {'Red': ExploitRemoteService 10.0.185.247}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f66b79c7e20>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dedc00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680def580>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 99 for RandomAgent
# action is: {'Red': HarakaRCE}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f66b79c7e20>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dedc00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680def580>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 107 for RandomAgent
# action is: {'Red': HTTPRFI}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f66b79c7e20>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dedc00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680def580>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 156 for RandomAgent
# action is: {'Red': RemoteCodeExecutionOnSMTP}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f66b79c7e20>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dedc00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680def580>}
# action is: {'Red': RemoteCodeExecutionOnSMTP, 'Blue': Sleep, 'Green': Sleep}
# --> in actions
# In simcontroller execute action
# action is: RemoteCodeExecutionOnSMTP its type is: <class 'CybORG.Simulator.Actions.ConcreteActions.ExploitActions.RemoteCodeExecutionOnSMTP.RemoteCodeExecutionOnSMTP'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# Action is 39 for RandomAgent
# action is: {'Red': BlueKeep}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f66b79c7e20>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dedc00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680def580>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 109 for RandomAgent
# action is: {'Red': HTTPRFI}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f66b79c7e20>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dedc00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680def580>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 144 for RandomAgent
# action is: {'Red': SQLInjection}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f66b79c7e20>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dedc00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680def580>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 203 for RandomAgent
# action is: {'Red': SSHBruteForce}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f66b79c7e20>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dedc00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680def580>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 57 for RandomAgent
# action is: {'Red': EternalBlue}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f66b79c7e20>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dedc00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680def580>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 192 for RandomAgent
# action is: {'Red': Impact User4}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f66b79c7e20>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dedc00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680def580>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 139 for RandomAgent
# action is: {'Red': SQLInjection}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f66b79c7e20>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dedc00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680def580>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 64 for RandomAgent
# action is: {'Red': EternalBlue}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f66b79c7e20>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dedc00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680def580>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 32 for RandomAgent
# action is: {'Red': ExploitRemoteService 10.0.33.105}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f66b79c7e20>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dedc00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680def580>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 145 for RandomAgent
# action is: {'Red': SQLInjection}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f66b79c7e20>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dedc00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680def580>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 116 for RandomAgent
# action is: {'Red': HTTPSRFI}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f66b79c7e20>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dedc00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680def580>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 117 for RandomAgent
# action is: {'Red': HTTPSRFI}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f66b79c7e20>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dedc00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680def580>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Training reward: 0.0
# Agent Interfaces are: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f66b78903d0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c12ce0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c13100>}
# Training Game: 2
# Action is 96 for RandomAgent
# action is: {'Red': HarakaRCE}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f66b78903d0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c12ce0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c13100>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 138 for RandomAgent
# action is: {'Red': SQLInjection}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f66b78903d0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c12ce0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c13100>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 43 for RandomAgent
# action is: {'Red': BlueKeep}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f66b78903d0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c12ce0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c13100>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 49 for RandomAgent
# action is: {'Red': BlueKeep}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f66b78903d0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c12ce0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c13100>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 25 for RandomAgent
# action is: {'Red': ExploitRemoteService 10.0.213.71}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f66b78903d0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c12ce0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c13100>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 34 for RandomAgent
# action is: {'Red': ExploitRemoteService 10.0.213.75}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f66b78903d0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c12ce0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c13100>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 28 for RandomAgent
# action is: {'Red': ExploitRemoteService 10.0.33.204}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f66b78903d0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c12ce0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c13100>}
# action is: {'Red': ExploitRemoteService 10.0.33.204, 'Blue': Sleep, 'Green': Sleep}
# --> in actions
# In simcontroller execute action
# action is: ExploitRemoteService 10.0.33.204 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.ExploitRemoteService.ExploitRemoteService'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# Action is 136 for RandomAgent
# action is: {'Red': SQLInjection}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f66b78903d0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c12ce0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c13100>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 200 for RandomAgent
# action is: {'Red': SSHBruteForce}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f66b78903d0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c12ce0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c13100>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 159 for RandomAgent
# action is: {'Red': RemoteCodeExecutionOnSMTP}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f66b78903d0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c12ce0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c13100>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 110 for RandomAgent
# action is: {'Red': HTTPRFI}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f66b78903d0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c12ce0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c13100>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 82 for RandomAgent
# action is: {'Red': FTPDirectoryTraversal}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f66b78903d0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c12ce0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c13100>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 208 for RandomAgent
# action is: {'Red': SSHBruteForce}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f66b78903d0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c12ce0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c13100>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 205 for RandomAgent
# action is: {'Red': SSHBruteForce}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f66b78903d0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c12ce0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c13100>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 135 for RandomAgent
# action is: {'Red': SQLInjection}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f66b78903d0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c12ce0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c13100>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 68 for RandomAgent
# action is: {'Red': FTPDirectoryTraversal}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f66b78903d0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c12ce0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c13100>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 46 for RandomAgent
# action is: {'Red': BlueKeep}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f66b78903d0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c12ce0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c13100>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 121 for RandomAgent
# action is: {'Red': HTTPSRFI}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f66b78903d0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c12ce0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c13100>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 138 for RandomAgent
# action is: {'Red': SQLInjection}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f66b78903d0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c12ce0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c13100>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 159 for RandomAgent
# action is: {'Red': RemoteCodeExecutionOnSMTP}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f66b78903d0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c12ce0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c13100>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Training reward: 0.0
# Agent Interfaces are: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c125f0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680b66a10>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680b67880>}
# Training Game: 3
# Action is 104 for RandomAgent
# action is: {'Red': HTTPRFI}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c125f0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680b66a10>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680b67880>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 60 for RandomAgent
# action is: {'Red': EternalBlue}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c125f0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680b66a10>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680b67880>}
# action is: {'Red': EternalBlue, 'Blue': Sleep, 'Green': Sleep}
# --> in actions
# In simcontroller execute action
# action is: EternalBlue its type is: <class 'CybORG.Simulator.Actions.ConcreteActions.ExploitActions.EternalBlue.EternalBlue'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# Action is 83 for RandomAgent
# action is: {'Red': FTPDirectoryTraversal}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c125f0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680b66a10>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680b67880>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 7 for RandomAgent
# action is: {'Red': DiscoverNetworkServices 10.0.205.56}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c125f0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680b66a10>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680b67880>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 26 for RandomAgent
# action is: {'Red': ExploitRemoteService 10.0.105.228}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c125f0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680b66a10>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680b67880>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 115 for RandomAgent
# action is: {'Red': HTTPRFI}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c125f0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680b66a10>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680b67880>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 139 for RandomAgent
# action is: {'Red': SQLInjection}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c125f0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680b66a10>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680b67880>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 71 for RandomAgent
# action is: {'Red': FTPDirectoryTraversal}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c125f0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680b66a10>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680b67880>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 85 for RandomAgent
# action is: {'Red': HarakaRCE}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c125f0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680b66a10>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680b67880>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 210 for RandomAgent
# action is: {'Red': SSHBruteForce}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c125f0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680b66a10>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680b67880>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 140 for RandomAgent
# action is: {'Red': SQLInjection}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c125f0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680b66a10>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680b67880>}
# action is: {'Red': SQLInjection, 'Blue': Sleep, 'Green': Sleep}
# --> in actions
# In simcontroller execute action
# action is: SQLInjection its type is: <class 'CybORG.Simulator.Actions.ConcreteActions.ExploitActions.SQLInjection.SQLInjection'>
# --> in end turn actions
# In simcontroller execute action
# ...
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53d60>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c51cc0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53a00>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 51 for RandomAgent
# action is: {'Red': BlueKeep}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53d60>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c51cc0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53a00>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 156 for RandomAgent
# action is: {'Red': RemoteCodeExecutionOnSMTP}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53d60>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c51cc0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c53a00>}
# action is: {'Red': RemoteCodeExecutionOnSMTP, 'Blue': Sleep, 'Green': Sleep}
# --> in actions
# In simcontroller execute action
# action is: RemoteCodeExecutionOnSMTP its type is: <class 'CybORG.Simulator.Actions.ConcreteActions.ExploitActions.RemoteCodeExecutionOnSMTP.RemoteCodeExecutionOnSMTP'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# Training reward: 0.0
# Agent Interfaces are: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680d7b3d0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dece80>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680deecb0>}
# Training Game: 19
# Action is 98 for RandomAgent
# action is: {'Red': HarakaRCE}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680d7b3d0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dece80>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680deecb0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 163 for RandomAgent
# action is: {'Red': RemoteCodeExecutionOnSMTP}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680d7b3d0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dece80>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680deecb0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 9 for RandomAgent
# action is: {'Red': DiscoverNetworkServices 10.0.107.94}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680d7b3d0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dece80>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680deecb0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 187 for RandomAgent
# action is: {'Red': Impact Op_Server0}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680d7b3d0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dece80>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680deecb0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 162 for RandomAgent
# action is: {'Red': RemoteCodeExecutionOnSMTP}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680d7b3d0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dece80>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680deecb0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 41 for RandomAgent
# action is: {'Red': BlueKeep}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680d7b3d0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dece80>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680deecb0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 158 for RandomAgent
# action is: {'Red': RemoteCodeExecutionOnSMTP}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680d7b3d0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dece80>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680deecb0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 176 for RandomAgent
# action is: {'Red': PrivilegeEscalate User4}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680d7b3d0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dece80>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680deecb0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 31 for RandomAgent
# action is: {'Red': ExploitRemoteService 10.0.228.119}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680d7b3d0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dece80>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680deecb0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 6 for RandomAgent
# action is: {'Red': DiscoverNetworkServices 10.0.77.124}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680d7b3d0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dece80>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680deecb0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 71 for RandomAgent
# action is: {'Red': FTPDirectoryTraversal}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680d7b3d0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dece80>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680deecb0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 7 for RandomAgent
# action is: {'Red': DiscoverNetworkServices 10.0.77.118}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680d7b3d0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dece80>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680deecb0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 161 for RandomAgent
# action is: {'Red': RemoteCodeExecutionOnSMTP}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680d7b3d0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dece80>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680deecb0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 170 for RandomAgent
# action is: {'Red': PrivilegeEscalate Op_Host2}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680d7b3d0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dece80>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680deecb0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 188 for RandomAgent
# action is: {'Red': Impact User0}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680d7b3d0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dece80>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680deecb0>}
# action is: {'Red': Impact User0, 'Blue': Sleep, 'Green': Sleep}
# --> in actions
# In simcontroller execute action
# action is: Impact User0 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Impact.Impact'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# Action is 174 for RandomAgent
# action is: {'Red': PrivilegeEscalate User2}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680d7b3d0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dece80>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680deecb0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 0 for RandomAgent
# action is: {'Red': Sleep}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680d7b3d0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dece80>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680deecb0>}
# action is: {'Red': Sleep, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Action is 60 for RandomAgent
# action is: {'Red': EternalBlue}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680d7b3d0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dece80>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680deecb0>}
# action is: {'Red': EternalBlue, 'Blue': Sleep, 'Green': Sleep}
# --> in actions
# In simcontroller execute action
# action is: EternalBlue its type is: <class 'CybORG.Simulator.Actions.ConcreteActions.ExploitActions.EternalBlue.EternalBlue'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# Action is 172 for RandomAgent
# action is: {'Red': PrivilegeEscalate User0}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680d7b3d0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dece80>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680deecb0>}
# action is: {'Red': PrivilegeEscalate User0, 'Blue': Sleep, 'Green': Sleep}
# --> in actions
# In simcontroller execute action
# action is: PrivilegeEscalate User0 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.PrivilegeEscalate.PrivilegeEscalate'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# Action is 113 for RandomAgent
# action is: {'Red': HTTPRFI}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680d7b3d0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680dece80>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680deecb0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Training reward: 0.0
# Agent Interfaces are: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c075b0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c07670>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f6680c05480>}

# %% [markdown]
# ### Q-Learning Agent

# %%
def run_training_example_q_learning(scenario):
    agent_name = 'Red'
    path = str(inspect.getfile(CybORG))
    path = path[:-7] + f'/Simulator/Scenarios/scenario_files/{scenario}.yaml'
    sg = FileReaderScenarioGenerator(path)
    cyborg = CybORG(scenario_generator=sg)
    cyborg = OpenAIGymWrapper(agent_name=agent_name,
                              env=FixedFlatWrapper(cyborg))

    observation = cyborg.reset()
    action_space = cyborg.action_space
    print(f"Observation size {len(observation)}, Action Size {action_space}")
    action_count = 0
    agent = RandomAgent()
    print(agent)
    agent.set_initial_values(action_space, observation)
    for i in range(MAX_EPS):  # laying multiple games
        print(f"\rTraining Game: {i}\n", end='', flush=True)
        reward = 0
        for j in range(MAX_STEPS_PER_GAME):  # step in 1 game
            action = agent.get_action(observation, action_space)
            next_observation, r, done, info = cyborg.step(action)

            action_space = cyborg.action_space
            reward += r

            agent.train(observation)  # training the agent
            observation = next_observation
            if done or j == MAX_STEPS_PER_GAME - 1:
                print(f"Training reward: {reward}")
                break
        agent.end_episode()
        observation = cyborg.reset()
        action_space = cyborg.action_space
        agent.set_initial_values(action_space, observation)

# %% [markdown]
# ### Deep RL Algorithms Agent

# %% [markdown]
# - PPO

# %%
#!pip install -U "ray[all]"

# %%
import inspect
import numpy as np
from CybORG import CybORG
from CybORG.Agents import B_lineAgent, GreenAgent
from CybORG.Agents.Wrappers import ChallengeWrapper

# %%
# from ray import tune

# tune.run(
#     "PPO",
#     config={
#         "env": "YourEnvName",
#         "num_gpus": 0,
#         "other_config_options": "...",
#     }
# )

# %%
# from ray.rllib.algorithms.ppo import PPOConfig

# config = (  # 1. Configure the algorithm,
#     PPOConfig()
#     .environment("Taxi-v3")
#     .rollouts(num_rollout_workers=2)
#     .framework("torch")
#     .training(model={"fcnet_hiddens": [64, 64]})
#     .evaluation(evaluation_num_workers=1)
# )

# algo = config.build()  # 2. build the algorithm,

# for _ in range(5):
#     print(algo.train())  # 3. train it,

# algo.evaluate()  # 4. and evaluate it.

# %%
from ray.rllib.algorithms import ppo
from ray.rllib.env import ParallelPettingZooEnv
from ray.tune import register_env

# %%
from CybORG.Agents.Wrappers.PettingZooParallelWrapper import PettingZooParallelWrapper
from CybORG.Simulator.Scenarios import FileReaderScenarioGenerator, DroneSwarmScenarioGenerator

# %%
class RLLibWrapper(ChallengeWrapper):
    def init(self, agent_name, env, reward_threshold=None, max_steps=None):
        super().__init__(agent_name, env, reward_threshold, max_steps)

    def step(self, action=None):
        obs, reward, done, info = self.env.step(action=action)
        self.step_counter += 1
        if self.max_steps is not None and self.step_counter >= self.max_steps:
            done = True
        return np.float32(obs), reward, done, info

    def reset(self):
        self.step_counter = 0
        obs = self.env.reset()
        return np.float32(obs)

# %%
def env_creator_CC1(env_config: dict):
    path = str(inspect.getfile(CybORG))
    path = path[:-7] + f'/Simulator/Scenarios/scenario_files/Scenario1b.yaml'
    sg = FileReaderScenarioGenerator(path)
    agents = {"Red": B_lineAgent(), "Green": GreenAgent()}
    cyborg = CybORG(scenario_generator=sg, environment='sim', agents=agents)
    env = RLLibWrapper(env=cyborg, agent_name="Blue", max_steps=100)
    return env

# %%
def env_creator_CC2(env_config: dict):
    path = str(inspect.getfile(CybORG))
    path = path[:-7] + f'/Simulator/Scenarios/scenario_files/Scenario2.yaml'
    sg = FileReaderScenarioGenerator(path)
    agents = {"Red": B_lineAgent(), "Green": GreenAgent()}
    cyborg = CybORG(scenario_generator=sg, environment='sim', agents=agents)
    env = RLLibWrapper(env=cyborg, agent_name="Blue", max_steps=100)
    return env

# %%
def env_creator_CC3(env_config: dict):
    sg = DroneSwarmScenarioGenerator()
    cyborg = CybORG(scenario_generator=sg, environment='sim')
    env = ParallelPettingZooEnv(PettingZooParallelWrapper(env=cyborg))
    return env

# %%
def print_results(results_dict):
    train_iter = results_dict["training_iteration"]
    r_mean = results_dict["episode_reward_mean"]
    r_max = results_dict["episode_reward_max"]
    r_min = results_dict["episode_reward_min"]
    print(f"{train_iter:4d} \tr_mean: {r_mean:.1f} \tr_max: {r_max:.1f} \tr_min: {r_min: .1f}")

# %%
if __name__ == "__main__":
    register_env(name="CC1", env_creator=env_creator_CC1)
    register_env(name="CC2", env_creator=env_creator_CC2)
    register_env(name="CC3", env_creator=env_creator_CC3)
    config = ppo.DEFAULT_CONFIG.copy()
    for env in ['CC1', 'CC2', 'CC3']:
        agent = ppo.PPOTrainer(config=config, env=env)

        train_steps = 1e2
        total_steps = 0
        while total_steps < train_steps:
            results = agent.train()
            print_results(results)
            total_steps = results["timesteps_total"]
