# %%
from CybORG import CybORG
import inspect
# Out:
# /home/ubuntu/.local/lib/python3.10/site-packages/gym/wrappers/monitoring/video_recorder.py:9: DeprecationWarning: The distutils package is deprecated and slated for removal in Python 3.12. Use setuptools or check PEP 632 for potential alternatives
#   import distutils.spawn
# path is: /home/ubuntu/CybORG/CybORG/env.py

# %%
from CybORG.Agents import RandomAgent
from CybORG.Agents.Wrappers import EnumActionWrapper
from CybORG.Agents.Wrappers.FixedFlatWrapper import FixedFlatWrapper
from CybORG.Agents.Wrappers.IntListToAction import IntListToActionWrapper
from CybORG.Agents.Wrappers.OpenAIGymWrapper import OpenAIGymWrapper
from CybORG.Simulator.Scenarios.FileReaderScenarioGenerator import FileReaderScenarioGenerator

# %%
MAX_STEPS_PER_GAME = 20
MAX_EPS = 20

# %%
def run_training_example(scenario):
    agent_name = 'Red'
    path = str(inspect.getfile(CybORG))
    path = path[:-7] + f'/Simulator/Scenarios/scenario_files/{scenario}.yaml'
    sg = FileReaderScenarioGenerator(path)
    cyborg = CybORG(scenario_generator=sg)
    cyborg = OpenAIGymWrapper(agent_name=agent_name,
                              env=FixedFlatWrapper(cyborg))

    observation = cyborg.reset()
    action_space = cyborg.action_space
    # print(f"Observation size {len(observation)}, Action Size {action_space}")
    action_count = 0
    agent = RandomAgent()
    agent.set_initial_values(action_space, observation)
    for i in range(MAX_EPS):  # laying multiple games
        # print(f"\rTraining Game: {i}", end='', flush=True)
        reward = 0
        for j in range(MAX_STEPS_PER_GAME):  # step in 1 game
            action = agent.get_action(observation, action_space)
            next_observation, r, done, info = cyborg.step(action)
            action_space = cyborg.action_space
            reward += r

            agent.train(observation)  # training the agent
            observation = next_observation
            if done or j == MAX_STEPS_PER_GAME - 1:
                # print(f"Training reward: {reward}")
                break
        agent.end_episode()
        observation = cyborg.reset()
        action_space = cyborg.action_space
        agent.set_initial_values(action_space, observation)

# %%
if __name__ == "__main__":
    run_training_example('Scenario1')
    print("Done")
# Out:
# env is: sim
# Agent Interfaces are: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129919fdf0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129919fdc0>}
# Agent Interfaces are: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129919c130>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129919e620>}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.6.222, Username: pi, Password: vagrant}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129919c130>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129919e620>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': SSHLoginExploit: MSF Session: 0, Target: 10.0.245.17:68}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129919c130>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129919e620>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.6.210, Username: GreenAgent, Password: vagrant}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129919c130>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129919e620>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.185.58, Username: vagrant, Password: raspberry}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129919c130>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129919e620>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': SSHLoginExploit: MSF Session: 0, Target: 10.0.185.58:135}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129919c130>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129919e620>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.185.58, Username: root, Password: vagrant}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129919c130>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129919e620>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': SSHLoginExploit: MSF Session: 0, Target: 10.0.185.55:80}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129919c130>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129919e620>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.185.55, Username: ubuntu, Password: raspberry}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129919c130>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129919e620>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MSFAutoroute: MSF Session: 0, Meterpreter Session: 7}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129919c130>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129919e620>}
# action is: {'Red': MSFAutoroute: MSF Session: 0, Meterpreter Session: 7, 'Blue': Sleep}
# --> in actions
# In simcontroller execute action
# action is: MSFAutoroute: MSF Session: 0, Meterpreter Session: 7 its type is: <class 'CybORG.Simulator.Actions.MSFActionsFolder.MSFAutoroute.MSFAutoroute'>
# --> in observations
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.185.58, Username: root, Password: vagrant}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129919c130>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129919e620>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MeterpreterIPConfig: MSF Session: 0, Meterpreter Session: 1}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129919c130>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129919e620>}
# action is: {'Red': MeterpreterIPConfig: MSF Session: 0, Meterpreter Session: 1, 'Blue': Sleep}
# --> in actions
# In simcontroller execute action
# action is: MeterpreterIPConfig: MSF Session: 0, Meterpreter Session: 1 its type is: <class 'CybORG.Simulator.Actions.MSFActionsFolder.MeterpreterActionsFolder.MeterpreterIPConfig.MeterpreterIPConfig'>
# --> in observations
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.185.58, Username: vagrant, Password: raspberry}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129919c130>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129919e620>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': UpgradeToMeterpreter: MSF Session: 0, Shell Session: 4}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129919c130>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129919e620>}
# action is: {'Red': UpgradeToMeterpreter: MSF Session: 0, Shell Session: 4, 'Blue': Sleep}
# --> in actions
# In simcontroller execute action
# action is: UpgradeToMeterpreter: MSF Session: 0, Shell Session: 4 its type is: <class 'CybORG.Simulator.Actions.MSFActionsFolder.UpgradeToMeterpreter.UpgradeToMeterpreter'>
# --> in observations
# action is: {'Red': SSHLoginExploit: MSF Session: 0, Target: 10.0.6.222:55553}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129919c130>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129919e620>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.245.24, Username: Administrator, Password: raspberry}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129919c130>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129919e620>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.6.218, Username: root, Password: raspberry}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129919c130>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129919e620>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.6.210, Username: SYSTEM, Password: raspberry}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129919c130>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129919e620>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.185.58, Username: ec2-user, Password: vagrant}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129919c130>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129919e620>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.6.222, Username: ec2-user, Password: raspberry}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129919c130>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129919e620>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.6.210, Username: ubuntu, Password: raspberry}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129919c130>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129919e620>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# Agent Interfaces are: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299105480>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299105d50>}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.246.164, Username: SYSTEM, Password: raspberry}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299105480>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299105d50>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.251.60, Username: root, Password: raspberry}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299105480>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299105d50>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.14.66, Username: pi, Password: vagrant}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299105480>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299105d50>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': SSHLoginExploit: MSF Session: 0, Target: 10.0.14.66:80}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299105480>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299105d50>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MeterpreterIPConfig: MSF Session: 0, Meterpreter Session: 2}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299105480>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299105d50>}
# action is: {'Red': MeterpreterIPConfig: MSF Session: 0, Meterpreter Session: 2, 'Blue': Sleep}
# --> in actions
# In simcontroller execute action
# action is: MeterpreterIPConfig: MSF Session: 0, Meterpreter Session: 2 its type is: <class 'CybORG.Simulator.Actions.MSFActionsFolder.MeterpreterActionsFolder.MeterpreterIPConfig.MeterpreterIPConfig'>
# --> in observations
# action is: {'Red': SSHLoginExploit: MSF Session: 0, Target: 10.0.251.56:53}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299105480>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299105d50>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.14.66, Username: root, Password: vagrant}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299105480>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299105d50>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MeterpreterIPConfig: MSF Session: 0, Meterpreter Session: 4}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299105480>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299105d50>}
# action is: {'Red': MeterpreterIPConfig: MSF Session: 0, Meterpreter Session: 4, 'Blue': Sleep}
# --> in actions
# In simcontroller execute action
# action is: MeterpreterIPConfig: MSF Session: 0, Meterpreter Session: 4 its type is: <class 'CybORG.Simulator.Actions.MSFActionsFolder.MeterpreterActionsFolder.MeterpreterIPConfig.MeterpreterIPConfig'>
# --> in observations
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.246.162, Username: ec2-user, Password: vagrant}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299105480>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299105d50>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': SSHLoginExploit: MSF Session: 0, Target: 10.0.251.56:22}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299105480>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299105d50>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.251.56, Username: root, Password: raspberry}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299105480>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299105d50>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.14.77, Username: root, Password: raspberry}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299105480>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299105d50>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.14.66, Username: pi, Password: vagrant}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299105480>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299105d50>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.14.77, Username: GreenAgent, Password: raspberry}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299105480>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299105d50>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.246.167, Username: vagrant, Password: vagrant}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299105480>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299105d50>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MSFPingsweep: MSF Session: 0, Subnet: 10.0.14.64/28, Client Session: 4}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299105480>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299105d50>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': SSHLoginExploit: MSF Session: 0, Target: 10.0.14.66:135}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299105480>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299105d50>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': SSHLoginExploit: MSF Session: 0, Target: 10.0.246.162:68}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299105480>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299105d50>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.246.162, Username: ubuntu, Password: raspberry}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299105480>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299105d50>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MSFPortscan: MSF Session: 0, Target: 10.0.251.56}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299105480>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299105d50>}
# action is: {'Red': MSFPortscan: MSF Session: 0, Target: 10.0.251.56, 'Blue': Sleep}
# --> in actions
# In simcontroller execute action
# action is: MSFPortscan: MSF Session: 0, Target: 10.0.251.56 its type is: <class 'CybORG.Simulator.Actions.MSFActionsFolder.MSFScannerFolder.MSFPortscan.MSFPortscan'>
# --> in observations
# Agent Interfaces are: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12cff7f6d0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299393b50>}
# action is: {'Red': SSHLoginExploit: MSF Session: 0, Target: 10.0.214.131:139}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12cff7f6d0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299393b50>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.241.246, Username: SYSTEM, Password: raspberry}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12cff7f6d0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299393b50>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.241.249, Username: GreenAgent, Password: vagrant}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12cff7f6d0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299393b50>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.10.115, Username: SYSTEM, Password: raspberry}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12cff7f6d0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299393b50>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.241.249, Username: pi, Password: vagrant}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12cff7f6d0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299393b50>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.214.131, Username: ubuntu, Password: vagrant}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12cff7f6d0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299393b50>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': SSHLoginExploit: MSF Session: 0, Target: 10.0.241.246:445}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12cff7f6d0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299393b50>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.214.131, Username: Administrator, Password: raspberry}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12cff7f6d0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299393b50>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MSFPingsweep: MSF Session: 0, Subnet: 10.0.214.128/28, Client Session: 3}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12cff7f6d0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299393b50>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.241.246, Username: vagrant, Password: vagrant}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12cff7f6d0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299393b50>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.10.124, Username: Administrator, Password: raspberry}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12cff7f6d0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299393b50>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MSFPortscan: MSF Session: 0, Target: 10.0.10.123}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12cff7f6d0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299393b50>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.241.246, Username: ec2-user, Password: vagrant}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12cff7f6d0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299393b50>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': SSHLoginExploit: MSF Session: 0, Target: 10.0.10.115:3389}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12cff7f6d0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299393b50>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.10.124, Username: GreenAgent, Password: vagrant}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12cff7f6d0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299393b50>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.10.123, Username: SYSTEM, Password: vagrant}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12cff7f6d0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299393b50>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': SSHLoginExploit: MSF Session: 0, Target: 10.0.241.246:53}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12cff7f6d0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299393b50>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.10.124, Username: pi, Password: vagrant}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12cff7f6d0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299393b50>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MSFPortscan: MSF Session: 0, Target: 10.0.10.123}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12cff7f6d0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299393b50>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.241.249, Username: ec2-user, Password: vagrant}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12cff7f6d0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299393b50>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# Agent Interfaces are: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129933e920>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993ba920>}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.208.180, Username: Administrator, Password: vagrant}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129933e920>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993ba920>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': SSHLoginExploit: MSF Session: 0, Target: 10.0.208.188:53}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129933e920>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993ba920>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': SSHLoginExploit: MSF Session: 0, Target: 10.0.121.69:53}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129933e920>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993ba920>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': SSHLoginExploit: MSF Session: 0, Target: 10.0.108.238:68}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129933e920>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993ba920>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.121.69, Username: vagrant, Password: vagrant}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129933e920>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993ba920>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.208.186, Username: GreenAgent, Password: vagrant}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129933e920>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993ba920>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MSFPingsweep: MSF Session: 0, Subnet: 10.0.108.224/28, Client Session: 1}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129933e920>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993ba920>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': SSHLoginExploit: MSF Session: 0, Target: 10.0.208.188:445}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129933e920>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993ba920>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.108.225, Username: www-data, Password: raspberry}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129933e920>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993ba920>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': SSHLoginExploit: MSF Session: 0, Target: 10.0.208.186:53}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129933e920>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993ba920>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MSFPingsweep: MSF Session: 0, Subnet: 10.0.108.224/28, Client Session: 0}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129933e920>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993ba920>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MSFPingsweep: MSF Session: 0, Subnet: 10.0.121.64/28, Client Session: 2}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129933e920>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993ba920>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MSFPingsweep: MSF Session: 0, Subnet: 10.0.121.64/28, Client Session: 7}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129933e920>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993ba920>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.121.65, Username: Administrator, Password: raspberry}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129933e920>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993ba920>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.121.65, Username: GreenAgent, Password: vagrant}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129933e920>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993ba920>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MeterpreterIPConfig: MSF Session: 0, Meterpreter Session: 5}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129933e920>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993ba920>}
# action is: {'Red': MeterpreterIPConfig: MSF Session: 0, Meterpreter Session: 5, 'Blue': Sleep}
# --> in actions
# In simcontroller execute action
# action is: MeterpreterIPConfig: MSF Session: 0, Meterpreter Session: 5 its type is: <class 'CybORG.Simulator.Actions.MSFActionsFolder.MeterpreterActionsFolder.MeterpreterIPConfig.MeterpreterIPConfig'>
# --> in observations
# action is: {'Red': MSFPingsweep: MSF Session: 0, Subnet: 10.0.121.64/28, Client Session: 4}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129933e920>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993ba920>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.121.65, Username: GreenAgent, Password: raspberry}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129933e920>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993ba920>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.208.180, Username: ubuntu, Password: vagrant}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129933e920>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993ba920>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': SSHLoginExploit: MSF Session: 0, Target: 10.0.108.225:55553}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f129933e920>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993ba920>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# Agent Interfaces are: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12cc60cd00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993b94b0>}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.225.182, Username: ubuntu, Password: vagrant}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12cc60cd00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993b94b0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.210.234, Username: vagrant, Password: raspberry}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12cc60cd00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993b94b0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.210.232, Username: GreenAgent, Password: raspberry}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12cc60cd00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993b94b0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': SSHLoginExploit: MSF Session: 0, Target: 10.0.72.254:443}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12cc60cd00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993b94b0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.225.182, Username: pi, Password: raspberry}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12cc60cd00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993b94b0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.72.254, Username: ubuntu, Password: raspberry}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12cc60cd00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993b94b0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.210.234, Username: pi, Password: vagrant}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12cc60cd00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993b94b0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.72.247, Username: SYSTEM, Password: raspberry}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12cc60cd00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993b94b0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.210.232, Username: ubuntu, Password: vagrant}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12cc60cd00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993b94b0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': UpgradeToMeterpreter: MSF Session: 0, Shell Session: 4}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12cc60cd00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993b94b0>}
# action is: {'Red': UpgradeToMeterpreter: MSF Session: 0, Shell Session: 4, 'Blue': Sleep}
# --> in actions
# In simcontroller execute action
# action is: UpgradeToMeterpreter: MSF Session: 0, Shell Session: 4 its type is: <class 'CybORG.Simulator.Actions.MSFActionsFolder.UpgradeToMeterpreter.UpgradeToMeterpreter'>
# --> in observations
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.72.247, Username: GreenAgent, Password: raspberry}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12cc60cd00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993b94b0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.225.182, Username: ec2-user, Password: raspberry}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12cc60cd00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993b94b0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': SSHLoginExploit: MSF Session: 0, Target: 10.0.210.234:443}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12cc60cd00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993b94b0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': SSHLoginExploit: MSF Session: 0, Target: 10.0.210.234:443}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12cc60cd00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993b94b0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': SSHLoginExploit: MSF Session: 0, Target: 10.0.210.234:3389}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12cc60cd00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993b94b0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': SSHLoginExploit: MSF Session: 0, Target: 10.0.72.243:80}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12cc60cd00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993b94b0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.72.247, Username: www-data, Password: vagrant}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12cc60cd00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993b94b0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': UpgradeToMeterpreter: MSF Session: 0, Shell Session: 6}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12cc60cd00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993b94b0>}
# action is: {'Red': UpgradeToMeterpreter: MSF Session: 0, Shell Session: 6, 'Blue': Sleep}
# --> in actions
# In simcontroller execute action
# action is: UpgradeToMeterpreter: MSF Session: 0, Shell Session: 6 its type is: <class 'CybORG.Simulator.Actions.MSFActionsFolder.UpgradeToMeterpreter.UpgradeToMeterpreter'>
# --> in observations
# action is: {'Red': SSHLoginExploit: MSF Session: 0, Target: 10.0.210.234:139}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12cc60cd00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993b94b0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.72.254, Username: ubuntu, Password: vagrant}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12cc60cd00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993b94b0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# Agent Interfaces are: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299392ef0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993921a0>}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.52.34, Username: www-data, Password: raspberry}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299392ef0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993921a0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MeterpreterIPConfig: MSF Session: 0, Meterpreter Session: 7}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299392ef0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993921a0>}
# action is: {'Red': MeterpreterIPConfig: MSF Session: 0, Meterpreter Session: 7, 'Blue': Sleep}
# --> in actions
# In simcontroller execute action
# action is: MeterpreterIPConfig: MSF Session: 0, Meterpreter Session: 7 its type is: <class 'CybORG.Simulator.Actions.MSFActionsFolder.MeterpreterActionsFolder.MeterpreterIPConfig.MeterpreterIPConfig'>
# --> in observations
# action is: {'Red': SSHLoginExploit: MSF Session: 0, Target: 10.0.116.66:443}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299392ef0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993921a0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.169.77, Username: www-data, Password: raspberry}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299392ef0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993921a0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.116.74, Username: ubuntu, Password: vagrant}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299392ef0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993921a0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.52.34, Username: ec2-user, Password: raspberry}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299392ef0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993921a0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.52.44, Username: vagrant, Password: raspberry}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299392ef0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993921a0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.169.67, Username: vagrant, Password: raspberry}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299392ef0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993921a0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.52.34, Username: SYSTEM, Password: vagrant}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299392ef0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993921a0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.116.74, Username: pi, Password: vagrant}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299392ef0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993921a0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': SSHLoginExploit: MSF Session: 0, Target: 10.0.116.66:3389}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299392ef0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993921a0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# ...
# action is: {'Red': MSFPingsweep: MSF Session: 0, Subnet: 10.0.69.240/28, Client Session: 3}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993ebb50>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993eaa40>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.89.186, Username: vagrant, Password: vagrant}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993ebb50>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993eaa40>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.126.9, Username: vagrant, Password: raspberry}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993ebb50>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993eaa40>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.126.10, Username: Administrator, Password: vagrant}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993ebb50>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993eaa40>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.126.10, Username: ubuntu, Password: vagrant}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993ebb50>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993eaa40>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': SSHLoginExploit: MSF Session: 0, Target: 10.0.89.186:3389}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993ebb50>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993eaa40>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MSFPortscan: MSF Session: 0, Target: 10.0.126.5}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993ebb50>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993eaa40>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.69.246, Username: www-data, Password: vagrant}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993ebb50>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993eaa40>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.126.5, Username: ec2-user, Password: vagrant}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993ebb50>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993eaa40>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': SSHLoginExploit: MSF Session: 0, Target: 10.0.69.246:80}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993ebb50>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993eaa40>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.126.5, Username: pi, Password: raspberry}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993ebb50>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993eaa40>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': SSHLoginExploit: MSF Session: 0, Target: 10.0.126.9:80}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993ebb50>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993eaa40>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.126.9, Username: vagrant, Password: raspberry}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993ebb50>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993eaa40>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.69.248, Username: pi, Password: raspberry}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993ebb50>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993eaa40>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': SSHLoginExploit: MSF Session: 0, Target: 10.0.126.10:22}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993ebb50>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993eaa40>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.126.10, Username: SYSTEM, Password: vagrant}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993ebb50>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993eaa40>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': SSHLoginExploit: MSF Session: 0, Target: 10.0.89.180:55553}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993ebb50>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12993eaa40>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# Agent Interfaces are: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12991064a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12991047f0>}
# action is: {'Red': SSHLoginExploit: MSF Session: 0, Target: 10.0.207.68:139}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12991064a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12991047f0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': SSHLoginExploit: MSF Session: 0, Target: 10.0.207.76:445}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12991064a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12991047f0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.166.20, Username: root, Password: raspberry}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12991064a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12991047f0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.125.44, Username: GreenAgent, Password: vagrant}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12991064a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12991047f0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MSFPingsweep: MSF Session: 0, Subnet: 10.0.166.16/28, Client Session: 3}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12991064a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12991047f0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': SSHLoginExploit: MSF Session: 0, Target: 10.0.166.30:80}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12991064a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12991047f0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': SSHLoginExploit: MSF Session: 0, Target: 10.0.207.76:3389}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12991064a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12991047f0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MSFPingsweep: MSF Session: 0, Subnet: 10.0.207.64/28, Client Session: 1}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12991064a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12991047f0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': SSHLoginExploit: MSF Session: 0, Target: 10.0.207.74:139}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12991064a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12991047f0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MSFPingsweep: MSF Session: 0, Subnet: 10.0.166.16/28, Client Session: 0}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12991064a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12991047f0>}
# action is: {'Red': MSFPingsweep: MSF Session: 0, Subnet: 10.0.166.16/28, Client Session: 0, 'Blue': Sleep}
# --> in actions
# In simcontroller execute action
# action is: MSFPingsweep: MSF Session: 0, Subnet: 10.0.166.16/28, Client Session: 0 its type is: <class 'CybORG.Simulator.Actions.MSFActionsFolder.MSFScannerFolder.MSFPingsweep.MSFPingsweep'>
# --> in observations
# action is: {'Red': SSHLoginExploit: MSF Session: 0, Target: 10.0.166.20:68}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12991064a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12991047f0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.166.20, Username: pi, Password: raspberry}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12991064a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12991047f0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': UpgradeToMeterpreter: MSF Session: 0, Shell Session: 2}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12991064a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12991047f0>}
# action is: {'Red': UpgradeToMeterpreter: MSF Session: 0, Shell Session: 2, 'Blue': Sleep}
# --> in actions
# In simcontroller execute action
# action is: UpgradeToMeterpreter: MSF Session: 0, Shell Session: 2 its type is: <class 'CybORG.Simulator.Actions.MSFActionsFolder.UpgradeToMeterpreter.UpgradeToMeterpreter'>
# --> in observations
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.166.20, Username: ubuntu, Password: raspberry}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12991064a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12991047f0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.166.30, Username: GreenAgent, Password: raspberry}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12991064a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12991047f0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': SSHLoginExploit: MSF Session: 0, Target: 10.0.207.74:55553}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12991064a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12991047f0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': UpgradeToMeterpreter: MSF Session: 0, Shell Session: 6}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12991064a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12991047f0>}
# action is: {'Red': UpgradeToMeterpreter: MSF Session: 0, Shell Session: 6, 'Blue': Sleep}
# --> in actions
# In simcontroller execute action
# action is: UpgradeToMeterpreter: MSF Session: 0, Shell Session: 6 its type is: <class 'CybORG.Simulator.Actions.MSFActionsFolder.UpgradeToMeterpreter.UpgradeToMeterpreter'>
# --> in observations
# action is: {'Red': SSHLoginExploit: MSF Session: 0, Target: 10.0.207.76:80}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12991064a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12991047f0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MS17_010_PSExec: MSF Session: 0, Target: 10.0.207.76, Username: ubuntu, Password: vagrant}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12991064a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12991047f0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep}
# action is: {'Red': MeterpreterIPConfig: MSF Session: 0, Meterpreter Session: 3}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12991064a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f12991047f0>}
# action is: {'Red': MeterpreterIPConfig: MSF Session: 0, Meterpreter Session: 3, 'Blue': Sleep}
# --> in actions
# In simcontroller execute action
# action is: MeterpreterIPConfig: MSF Session: 0, Meterpreter Session: 3 its type is: <class 'CybORG.Simulator.Actions.MSFActionsFolder.MeterpreterActionsFolder.MeterpreterIPConfig.MeterpreterIPConfig'>
# --> in observations
# Agent Interfaces are: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299107f70>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7f1299107460>}
# Done
