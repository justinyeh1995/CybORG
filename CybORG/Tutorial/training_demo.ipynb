# %%
from CybORG import CybORG
import inspect
import pprint

from CybORG.Agents import RandomAgent
from CybORG.Agents.Wrappers import EnumActionWrapper
from CybORG.Agents.Wrappers.FixedFlatWrapper import FixedFlatWrapper
from CybORG.Agents.Wrappers.IntListToAction import IntListToActionWrapper
from CybORG.Agents.Wrappers.OpenAIGymWrapper import OpenAIGymWrapper
from CybORG.Simulator.Scenarios.FileReaderScenarioGenerator import FileReaderScenarioGenerator

# %%
MAX_STEPS_PER_GAME = 20
MAX_EPS = 20

# %%
def run_training_example(scenario):
    agent_name = 'Red'
    path = str(inspect.getfile(CybORG))
    path = path[:-7] + f'/Simulator/Scenarios/scenario_files/{scenario}.yaml'
    sg = FileReaderScenarioGenerator(path)
    cyborg = CybORG(scenario_generator=sg)
    cyborg = OpenAIGymWrapper(agent_name=agent_name,
                              env=FixedFlatWrapper(cyborg))

    observation = cyborg.reset()
    action_space = cyborg.action_space
    print(f"Observation size {len(observation)}, Action Size {action_space}")
    action_count = 0
    agent = RandomAgent()
    print(agent)
    agent.set_initial_values(action_space, observation)
    for i in range(MAX_EPS):  # laying multiple games
        print(f"\rTraining Game: {i}\n", end='', flush=True)
        reward = 0
        for j in range(MAX_STEPS_PER_GAME):  # step in 1 game
            action = agent.get_action(observation, action_space)
            next_observation, r, done, info = cyborg.step(action)

            action_space = cyborg.action_space
            reward += r

            agent.train(observation)  # training the agent
            observation = next_observation
            if done or j == MAX_STEPS_PER_GAME - 1:
                print(f"Training reward: {reward}")
                break
        agent.end_episode()
        observation = cyborg.reset()
        action_space = cyborg.action_space
        agent.set_initial_values(action_space, observation)

# %%
run_training_example('Scenario2')
# Out:
# env is: sim
# Agent Interfaces are: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c80c70>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8ba55a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb92f9fd8d0>}
# Agent Interfaces are: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8cb5150>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8cb5f00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8dc1d20>}
# Observation size 11293, Action Size Discrete(212)
# RandomAgent
# Training Game: 0
# action is: {'Red': PrivilegeEscalate User0}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8cb5150>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8cb5f00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8dc1d20>}
# action is: {'Red': PrivilegeEscalate User0, 'Blue': Sleep, 'Green': Sleep}
# --> in actions
# In simcontroller execute action
# action is: PrivilegeEscalate User0 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.PrivilegeEscalate.PrivilegeEscalate'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# action is: {'Red': HarakaRCE}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8cb5150>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8cb5f00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8dc1d20>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': Impact User0}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8cb5150>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8cb5f00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8dc1d20>}
# action is: {'Red': Impact User0, 'Blue': Sleep, 'Green': Sleep}
# --> in actions
# In simcontroller execute action
# action is: Impact User0 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Impact.Impact'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# action is: {'Red': SSHBruteForce}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8cb5150>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8cb5f00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8dc1d20>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': ExploitRemoteService 10.0.172.86}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8cb5150>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8cb5f00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8dc1d20>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': SQLInjection}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8cb5150>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8cb5f00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8dc1d20>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': Impact Enterprise2}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8cb5150>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8cb5f00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8dc1d20>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': HarakaRCE}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8cb5150>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8cb5f00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8dc1d20>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': SQLInjection}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8cb5150>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8cb5f00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8dc1d20>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': SSHBruteForce}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8cb5150>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8cb5f00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8dc1d20>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': RemoteCodeExecutionOnSMTP}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8cb5150>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8cb5f00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8dc1d20>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': SQLInjection}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8cb5150>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8cb5f00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8dc1d20>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': SSHBruteForce}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8cb5150>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8cb5f00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8dc1d20>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': FTPDirectoryTraversal}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8cb5150>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8cb5f00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8dc1d20>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': BlueKeep}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8cb5150>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8cb5f00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8dc1d20>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': PrivilegeEscalate User0}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8cb5150>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8cb5f00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8dc1d20>}
# action is: {'Red': PrivilegeEscalate User0, 'Blue': Sleep, 'Green': Sleep}
# --> in actions
# In simcontroller execute action
# action is: PrivilegeEscalate User0 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.PrivilegeEscalate.PrivilegeEscalate'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# action is: {'Red': SQLInjection}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8cb5150>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8cb5f00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8dc1d20>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': DiscoverNetworkServices 10.0.164.148}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8cb5150>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8cb5f00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8dc1d20>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': EternalBlue}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8cb5150>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8cb5f00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8dc1d20>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': DiscoverNetworkServices 10.0.164.150}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8cb5150>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8cb5f00>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8dc1d20>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Training reward: 0.0
# Agent Interfaces are: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8bd3af0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c115a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f89601c0>}
# Training Game: 1
# action is: {'Red': PrivilegeEscalate Operational_router}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8bd3af0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c115a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f89601c0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': HarakaRCE}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8bd3af0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c115a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f89601c0>}
# action is: {'Red': HarakaRCE, 'Blue': Sleep, 'Green': Sleep}
# --> in actions
# In simcontroller execute action
# action is: HarakaRCE its type is: <class 'CybORG.Simulator.Actions.ConcreteActions.ExploitActions.HarakaRCE.HarakaRCE'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# action is: {'Red': EternalBlue}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8bd3af0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c115a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f89601c0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': RemoteCodeExecutionOnSMTP}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8bd3af0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c115a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f89601c0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': SSHBruteForce}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8bd3af0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c115a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f89601c0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': HTTPSRFI}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8bd3af0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c115a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f89601c0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': BlueKeep}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8bd3af0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c115a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f89601c0>}
# action is: {'Red': BlueKeep, 'Blue': Sleep, 'Green': Sleep}
# --> in actions
# In simcontroller execute action
# action is: BlueKeep its type is: <class 'CybORG.Simulator.Actions.ConcreteActions.ExploitActions.BlueKeep.BlueKeep'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# action is: {'Red': Impact User0}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8bd3af0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c115a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f89601c0>}
# action is: {'Red': Impact User0, 'Blue': Sleep, 'Green': Sleep}
# --> in actions
# In simcontroller execute action
# action is: Impact User0 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Impact.Impact'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# action is: {'Red': HTTPSRFI}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8bd3af0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c115a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f89601c0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': FTPDirectoryTraversal}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8bd3af0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c115a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f89601c0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': HTTPSRFI}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8bd3af0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c115a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f89601c0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': EternalBlue}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8bd3af0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c115a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f89601c0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': RemoteCodeExecutionOnSMTP}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8bd3af0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c115a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f89601c0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': DiscoverNetworkServices 10.0.245.69}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8bd3af0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c115a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f89601c0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': BlueKeep}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8bd3af0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c115a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f89601c0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': HTTPSRFI}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8bd3af0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c115a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f89601c0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': EternalBlue}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8bd3af0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c115a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f89601c0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': Impact User0}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8bd3af0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c115a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f89601c0>}
# action is: {'Red': Impact User0, 'Blue': Sleep, 'Green': Sleep}
# --> in actions
# In simcontroller execute action
# action is: Impact User0 its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Impact.Impact'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# action is: {'Red': SQLInjection}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8bd3af0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c115a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f89601c0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': HTTPSRFI}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8bd3af0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c115a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f89601c0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Training reward: 0.0
# Agent Interfaces are: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8dc1180>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c279a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8d4a140>}
# Training Game: 2
# action is: {'Red': EternalBlue}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8dc1180>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c279a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8d4a140>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': SQLInjection}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8dc1180>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c279a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8d4a140>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': BlueKeep}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8dc1180>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c279a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8d4a140>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': FTPDirectoryTraversal}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8dc1180>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c279a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8d4a140>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': RemoteCodeExecutionOnSMTP}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8dc1180>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c279a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8d4a140>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': DiscoverNetworkServices 10.0.243.228}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8dc1180>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c279a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8d4a140>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': PrivilegeEscalate Operational_router}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8dc1180>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c279a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8d4a140>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': SSHBruteForce}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8dc1180>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c279a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8d4a140>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': DiscoverNetworkServices 10.0.195.204}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8dc1180>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c279a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8d4a140>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': BlueKeep}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8dc1180>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c279a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8d4a140>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': DiscoverRemoteSystems 10.0.195.192/28}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8dc1180>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c279a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8d4a140>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': RemoteCodeExecutionOnSMTP}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8dc1180>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c279a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8d4a140>}
# action is: {'Red': RemoteCodeExecutionOnSMTP, 'Blue': Sleep, 'Green': Sleep}
# --> in actions
# In simcontroller execute action
# action is: RemoteCodeExecutionOnSMTP its type is: <class 'CybORG.Simulator.Actions.ConcreteActions.ExploitActions.RemoteCodeExecutionOnSMTP.RemoteCodeExecutionOnSMTP'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# action is: {'Red': EternalBlue}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8dc1180>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c279a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8d4a140>}
# action is: {'Red': EternalBlue, 'Blue': Sleep, 'Green': Sleep}
# --> in actions
# In simcontroller execute action
# action is: EternalBlue its type is: <class 'CybORG.Simulator.Actions.ConcreteActions.ExploitActions.EternalBlue.EternalBlue'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# action is: {'Red': RemoteCodeExecutionOnSMTP}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8dc1180>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c279a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8d4a140>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': FTPDirectoryTraversal}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8dc1180>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c279a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8d4a140>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': EternalBlue}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8dc1180>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c279a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8d4a140>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': PrivilegeEscalate Op_Host2}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8dc1180>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c279a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8d4a140>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': RemoteCodeExecutionOnSMTP}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8dc1180>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c279a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8d4a140>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': HarakaRCE}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8dc1180>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c279a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8d4a140>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': HTTPRFI}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8dc1180>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c279a0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8d4a140>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Training reward: 0.0
# Agent Interfaces are: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8a09de0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8a0b6d0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8a08fa0>}
# Training Game: 3
# action is: {'Red': ExploitRemoteService 10.0.66.33}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8a09de0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8a0b6d0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8a08fa0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': HarakaRCE}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8a09de0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8a0b6d0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8a08fa0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': SQLInjection}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8a09de0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8a0b6d0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8a08fa0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': EternalBlue}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8a09de0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8a0b6d0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8a08fa0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': HTTPRFI}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8a09de0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8a0b6d0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8a08fa0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': HTTPRFI}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8a09de0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8a0b6d0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8a08fa0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': EternalBlue}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8a09de0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8a0b6d0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8a08fa0>}
# action is: {'Red': EternalBlue, 'Blue': Sleep, 'Green': Sleep}
# --> in actions
# In simcontroller execute action
# action is: EternalBlue its type is: <class 'CybORG.Simulator.Actions.ConcreteActions.ExploitActions.EternalBlue.EternalBlue'>
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# --> in observations
# action is: {'Red': DiscoverNetworkServices 10.0.170.49}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8a09de0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8a0b6d0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8a08fa0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': HTTPSRFI}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8a09de0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8a0b6d0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8a08fa0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': Impact Enterprise2}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8a09de0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8a0b6d0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8a08fa0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': HarakaRCE}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8a09de0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8a0b6d0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8a08fa0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': SQLInjection}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8a09de0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8a0b6d0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8a08fa0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': FTPDirectoryTraversal}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8a09de0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8a0b6d0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8a08fa0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': PrivilegeEscalate Operational_router}
# In SimulationController script
# In shared EnvironmentController script
# ...
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': BlueKeep}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c2fe80>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c2fd30>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c2f040>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': DiscoverNetworkServices 10.0.130.133}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c2fe80>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c2fd30>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c2f040>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': ExploitRemoteService 10.0.89.163}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c2fe80>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c2fd30>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c2f040>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': ExploitRemoteService 10.0.146.100}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c2fe80>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c2fd30>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c2f040>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': ExploitRemoteService 10.0.146.103}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c2fe80>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c2fd30>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c2f040>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Training reward: 0.0
# Agent Interfaces are: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c257b0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb92f9fce80>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8ba58a0>}
# Training Game: 19
# action is: {'Red': SSHBruteForce}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c257b0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb92f9fce80>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8ba58a0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': HarakaRCE}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c257b0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb92f9fce80>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8ba58a0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': BlueKeep}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c257b0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb92f9fce80>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8ba58a0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': EternalBlue}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c257b0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb92f9fce80>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8ba58a0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': PrivilegeEscalate Enterprise0}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c257b0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb92f9fce80>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8ba58a0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': Impact Op_Host2}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c257b0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb92f9fce80>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8ba58a0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': SQLInjection}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c257b0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb92f9fce80>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8ba58a0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': BlueKeep}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c257b0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb92f9fce80>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8ba58a0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': SSHBruteForce}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c257b0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb92f9fce80>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8ba58a0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': DiscoverNetworkServices 10.0.202.106}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c257b0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb92f9fce80>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8ba58a0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': HTTPRFI}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c257b0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb92f9fce80>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8ba58a0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': HTTPRFI}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c257b0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb92f9fce80>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8ba58a0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': ExploitRemoteService 10.0.174.232}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c257b0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb92f9fce80>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8ba58a0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': ExploitRemoteService 10.0.99.6}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c257b0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb92f9fce80>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8ba58a0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': DiscoverNetworkServices 10.0.202.108}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c257b0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb92f9fce80>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8ba58a0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': FTPDirectoryTraversal}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c257b0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb92f9fce80>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8ba58a0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': HTTPSRFI}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c257b0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb92f9fce80>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8ba58a0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': SQLInjection}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c257b0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb92f9fce80>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8ba58a0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': SSHBruteForce}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c257b0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb92f9fce80>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8ba58a0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# action is: {'Red': ExploitRemoteService 10.0.202.108}
# In SimulationController script
# In shared EnvironmentController script
# Agent interface: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c257b0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb92f9fce80>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8ba58a0>}
# action is: {'Red': InvalidAction, 'Blue': Sleep, 'Green': Sleep}
# --> in end turn actions
# In simcontroller execute action
# action is: Monitor its type is: <class 'CybORG.Simulator.Actions.AbstractActions.Monitor.Monitor'>
# --> in observations
# Training reward: 0.0
# Agent Interfaces are: {'Blue': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f90732e0>, 'Green': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c59cf0>, 'Red': <CybORG.Shared.AgentInterface.AgentInterface object at 0x7fb8f8c596f0>}
